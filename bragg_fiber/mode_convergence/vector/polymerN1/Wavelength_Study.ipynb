# %% [markdown]
# # Do the wavelength study for the hollow glass tube with polymer
#
# Do it for both lossy and non-lossy polymer.  Both with air outside.

# %%
import numpy as np
import matplotlib.pyplot as plt


from fiberamp.fiber.microstruct.bragg import BraggExact
from step_exact import plotlogf
from scipy.optimize import newton
# Out:
# importing NGSolve-6.2.2203-56-g47f483033

# %% [markdown]
# # Initialize

# %%
n = 200
wls = np.linspace(1.5e-6, 1.585e-6, n+1)
betas1 = np.zeros_like(wls, dtype=complex)
outer = 'h2'
nu = 1

n_air = 1.00027717
n_glass = 1.4388164768221814
n_poly = 1.5

# %%
ts = [15*2.7183333333333333e-6, 15*2/3*1e-6, 15*2.7183333333333333e-6, 15*2e-6]
ns = [lambda x:n_air, lambda x:n_glass, lambda x:n_poly, lambda x:n_air]
mats = ['air','glass', 'polymer','air']
maxhs = [10,10,10,10]

# %%
for i, wl in enumerate(wls):
    print(5 * ' ' +  + 20 * '-' + '  ' + str(i+1) + '/' + str(n+1) + ': ' +
          'wavelength: ' +  str(wls[i]) + '  ' +  20 * '-' +5 * ' '+'\n')
    
    A = BraggExact(ts=ts, ns=ns , mats=mats,maxhs=maxhs, wl=wl)
    k_low = A.ks[0] * A.scale
    guess = np.array(.9999 * k_low)
    imag = 0
    flag = True
    reduce = 0

    while flag:
        try:
            x0 = np.array(guess + imag*1j)
            beta = newton(A.determinant, x0, args=(nu, outer), tol = 1e-17)
            if beta.real > k_low:
                print("Captured wrong mode, retrying.")
                raise RuntimeError
            elif beta.imag > 0:
                print("Positive imaginary part, retrying.")
                imag = -beta.imag
                guess *= 1/.999995
                raise RuntimeError
            else:
                print("Scaled beta: ", beta, ". Residual of determinant: ", 
                      abs(A.determinant(beta, nu, outer)), '\n\n' )
                imag = beta.imag
                flag=False
        except RuntimeError:
            guess *= .999995
            reduce += 1
            print("scaling guess: " + str(reduce), flush=True)
    betas1[i] = beta
# Out:
#      --------------------  1/201: wavelength: 1.5e-06  --------------------
#
# Scaled beta:  (62.8430631308646-2.585634215449467e-06j) . Residual of determinant:  7.301104874604744e-11
#
#
#      --------------------  2/201: wavelength: 1.5004250000000001e-06  --------------------
#
# Scaled beta:  (62.82525178294929-2.5340398915404364e-06j) . Residual of determinant:  3.75958676731498e-10
#
#
#      --------------------  3/201: wavelength: 1.50085e-06  --------------------
#
# Scaled beta:  (62.80745064000699-2.5057626448589353e-06j) . Residual of determinant:  4.0851696216765616e-10
#
#
#      --------------------  4/201: wavelength: 1.501275e-06  --------------------
#
# Scaled beta:  (62.78965962808839-2.499729866681339e-06j) . Residual of determinant:  9.522135455733405e-10
#
#
#      --------------------  5/201: wavelength: 1.5017e-06  --------------------
#
# Scaled beta:  (62.77187867559247-2.515669125064867e-06j) . Residual of determinant:  2.616010363423179e-10
#
#
#      --------------------  6/201: wavelength: 1.502125e-06  --------------------
#
# Scaled beta:  (62.754107711020715-2.5540848050882186e-06j) . Residual of determinant:  2.0970472179851197e-10
#
#
#      --------------------  7/201: wavelength: 1.5025500000000001e-06  --------------------
#
# Scaled beta:  (62.736346660747444-2.616293656946646e-06j) . Residual of determinant:  4.07011565221519e-10
#
#
#      --------------------  8/201: wavelength: 1.502975e-06  --------------------
#
# Scaled beta:  (62.718595446635334-2.7045237096092323e-06j) . Residual of determinant:  2.270691453891356e-10
#
#
#      --------------------  9/201: wavelength: 1.5034e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# scaling guess: 4
# scaling guess: 5
# Scaled beta:  (62.70085398330785-2.8220896565279194e-06j) . Residual of determinant:  1.9743371995867417e-10
#
#
#      --------------------  10/201: wavelength: 1.503825e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (62.68312217484221-2.973669195919501e-06j) . Residual of determinant:  3.621028471249868e-11
#
#
#      --------------------  11/201: wavelength: 1.50425e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (62.665399910565284-3.165721586134943e-06j) . Residual of determinant:  1.6817904518144175e-10
#
#
#      --------------------  12/201: wavelength: 1.5046750000000001e-06  --------------------
#
# Scaled beta:  (62.6476870594966-3.4071162859109298e-06j) . Residual of determinant:  1.5784257289903746e-10
#
#
#      --------------------  13/201: wavelength: 1.5051e-06  --------------------
#
# Scaled beta:  (62.62998346275763-3.7100838935663696e-06j) . Residual of determinant:  1.1478662569763767e-10
#
#
#      --------------------  14/201: wavelength: 1.505525e-06  --------------------
#
# Scaled beta:  (62.6122889228905-4.091678519678348e-06j) . Residual of determinant:  8.502608044272383e-11
#
#
#      --------------------  15/201: wavelength: 1.50595e-06  --------------------
#
# Scaled beta:  (62.5946031883923-4.576079318793955e-06j) . Residual of determinant:  9.563061964344773e-11
#
#
#      --------------------  16/201: wavelength: 1.506375e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (62.576925930654454-5.198318772467541e-06j) . Residual of determinant:  9.517105647032401e-11
#
#
#      --------------------  17/201: wavelength: 1.5068000000000001e-06  --------------------
#
# Scaled beta:  (62.55925670847146-6.010534594608579e-06j) . Residual of determinant:  4.972530682476975e-11
#
#
#      --------------------  18/201: wavelength: 1.507225e-06  --------------------
#
# Scaled beta:  (62.541594911448755-7.09289174220032e-06j) . Residual of determinant:  7.05332694372146e-11
#
#
#      --------------------  19/201: wavelength: 1.50765e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (62.52393966601304-8.57361449191724e-06j) . Residual of determinant:  1.4881803958835883e-10
#
#
#      --------------------  20/201: wavelength: 1.508075e-06  --------------------
#
# Scaled beta:  (62.50628967165328-1.0667938033299554e-05j) . Residual of determinant:  1.8322977420110126e-10
#
#
#      --------------------  21/201: wavelength: 1.5085e-06  --------------------
#
# Scaled beta:  (62.48864289871476-1.3759446675455866e-05j) . Residual of determinant:  2.2675026324769398e-11
#
#
#      --------------------  22/201: wavelength: 1.5089250000000001e-06  --------------------
#
# Scaled beta:  (62.470995989960215-1.8585722801322693e-05j) . Residual of determinant:  2.5175634328704535e-11
#
#
#      --------------------  23/201: wavelength: 1.50935e-06  --------------------
#
# Scaled beta:  (62.45334296594938-2.671329801914782e-05j) . Residual of determinant:  7.500546804623643e-11
#
#
#      --------------------  24/201: wavelength: 1.509775e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (62.43567208758084-4.195200913401815e-05j) . Residual of determinant:  4.387357331641857e-11
#
#
#      --------------------  25/201: wavelength: 1.5102e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (62.41795704046427-7.556100253057592e-05j) . Residual of determinant:  6.5347331425996304e-12
#
#
#      --------------------  26/201: wavelength: 1.510625e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (62.40012723349628-0.00017243694676107873j) . Residual of determinant:  1.5002574693631798e-12
#
#
#      --------------------  27/201: wavelength: 1.5110500000000001e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# scaling guess: 4
# scaling guess: 5
# scaling guess: 6
# Scaled beta:  (62.381962902248965-0.0006199792404783296j) . Residual of determinant:  2.4803211054031263e-12
#
#
#      --------------------  28/201: wavelength: 1.511475e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# scaling guess: 4
# scaling guess: 5
# scaling guess: 6
# scaling guess: 7
# scaling guess: 8
# scaling guess: 9
# scaling guess: 10
# scaling guess: 11
# scaling guess: 12
# scaling guess: 13
# scaling guess: 14
# scaling guess: 15
# scaling guess: 16
# scaling guess: 17
# scaling guess: 18
# scaling guess: 19
# scaling guess: 20
# scaling guess: 21
# Scaled beta:  (62.36154407307256-0.004851965779069292j) . Residual of determinant:  1.1103385707115857e-13
#
#
#      --------------------  29/201: wavelength: 1.5119e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# scaling guess: 4
# scaling guess: 5
# scaling guess: 6
# scaling guess: 7
# scaling guess: 8
# scaling guess: 9
# scaling guess: 10
# scaling guess: 11
# scaling guess: 12
# scaling guess: 13
# scaling guess: 14
# scaling guess: 15
# scaling guess: 16
# scaling guess: 17
# scaling guess: 18
# scaling guess: 19
# scaling guess: 20
# Scaled beta:  (62.33915684230932-0.003561170271233712j) . Residual of determinant:  6.904129207271622e-14
#
#
#      --------------------  30/201: wavelength: 1.512325e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (62.33159766989091-0.00011802823465703437j) . Residual of determinant:  2.0730148875359544e-11
#
#
#      --------------------  31/201: wavelength: 1.51275e-06  --------------------
#
# Scaled beta:  (62.313816400612865-5.75208367586995e-05j) . Residual of determinant:  8.184469259001707e-12
#
#
#      --------------------  32/201: wavelength: 1.5131750000000001e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# Scaled beta:  (62.29617420386596-3.418067631174561e-05j) . Residual of determinant:  2.802867209763107e-12
#
#
#      --------------------  33/201: wavelength: 1.5136e-06  --------------------
#
# Scaled beta:  (62.27859468036466-2.2786614444425548e-05j) . Residual of determinant:  2.4598926721158036e-12
#
#
#      --------------------  34/201: wavelength: 1.514025e-06  --------------------
#
# Scaled beta:  (62.26105177331931-1.6388932033491008e-05j) . Residual of determinant:  6.491880446928306e-11
#
#
#      --------------------  35/201: wavelength: 1.51445e-06  --------------------
#
# Scaled beta:  (62.24353412568353-1.244549127259493e-05j) . Residual of determinant:  1.484587526529732e-11
#
#
#      --------------------  36/201: wavelength: 1.514875e-06  --------------------
#
# Scaled beta:  (62.22603598718579-9.847470321727394e-06j) . Residual of determinant:  1.3940170606296984e-10
#
#
#      --------------------  37/201: wavelength: 1.5153000000000001e-06  --------------------
# Scaled beta:  (62.20855413068972-8.048643748765078e-06j) . Residual of determinant:  5.8177890324373685e-11
#
#
#      --------------------  38/201: wavelength: 1.515725e-06  --------------------
#
# Scaled beta:  (62.19108660228084-6.754681657962003e-06j) . Residual of determinant:  5.832885504300407e-11
#
#
#      --------------------  39/201: wavelength: 1.51615e-06  --------------------
#
# Scaled beta:  (62.173632147297376-5.795657398413693e-06j) . Residual of determinant:  2.617890919339009e-10
#
#
#      --------------------  40/201: wavelength: 1.516575e-06  --------------------
#
# Scaled beta:  (62.156189921032016-5.0679505199801766e-06j) . Residual of determinant:  1.3492595884031797e-10
#
#
#      --------------------  41/201: wavelength: 1.517e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (62.13875933193486-4.505511601477071e-06j) . Residual of determinant:  1.70072966571745e-10
#
#
#      --------------------  42/201: wavelength: 1.5174250000000001e-06  --------------------
#
# Scaled beta:  (62.121339951514976-4.064680442718315e-06j) . Residual of determinant:  3.0620383099778695e-11
#
#
#      --------------------  43/201: wavelength: 1.51785e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (62.103931460005505-3.7157176525977913e-06j) . Residual of determinant:  1.0287455439554524e-10
#
#
#      --------------------  44/201: wavelength: 1.518275e-06  --------------------
#
# Scaled beta:  (62.08653361222923-3.437861865180089e-06j) . Residual of determinant:  1.9047379484109877e-10
#
#
#      --------------------  45/201: wavelength: 1.5187e-06  --------------------
#
# Scaled beta:  (62.06914621538201-3.2163323617928648e-06j) . Residual of determinant:  1.758102978412629e-10
#
#
#      --------------------  46/201: wavelength: 1.519125e-06  --------------------
#
# Scaled beta:  (62.05176911410924-3.0404518958423883e-06j) . Residual of determinant:  1.5276973655158638e-10
#
#
#      --------------------  47/201: wavelength: 1.5195500000000001e-06  --------------------
#
# Scaled beta:  (62.03440218018537-2.902439236486819e-06j) . Residual of determinant:  1.7636937437540965e-11
#
#
#      --------------------  48/201: wavelength: 1.519975e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (62.01704530517218-2.796616002994568e-06j) . Residual of determinant:  1.0835362431061997e-10
#
#
#      --------------------  49/201: wavelength: 1.5204e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.999698395042664-2.718878258942386e-06j) . Residual of determinant:  3.2771496938139795e-10
#
#
#      --------------------  50/201: wavelength: 1.520825e-06  --------------------
#
# Scaled beta:  (61.9823613661167-2.6663430711853383e-06j) . Residual of determinant:  2.810655348457656e-10
#
#
#      --------------------  51/201: wavelength: 1.52125e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.96503414187182-2.6371152055107407e-06j) . Residual of determinant:  1.0106240755550473e-09
#
#
#      --------------------  52/201: wavelength: 1.5216750000000001e-06  --------------------
#
# Scaled beta:  (61.94771665032622-2.630140430904746e-06j) . Residual of determinant:  1.8645068208055277e-10
#
#
#      --------------------  53/201: wavelength: 1.5221e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.93040882177013-2.6451255484467356e-06j) . Residual of determinant:  2.549155271449333e-10
#
#
#      --------------------  54/201: wavelength: 1.522525e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.913110586670655-2.6825146747639558e-06j) . Residual of determinant:  3.3336682019295896e-10
#
#
#      --------------------  55/201: wavelength: 1.52295e-06  --------------------
#
# Scaled beta:  (61.89582187359574-2.7435185956707725e-06j) . Residual of determinant:  1.5506492728757136e-11
#
#
#      --------------------  56/201: wavelength: 1.523375e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (61.878542607007645-2.830200643504419e-06j) . Residual of determinant:  1.0577148854173466e-10
#
#
#      --------------------  57/201: wavelength: 1.5238000000000001e-06  --------------------
#
# Scaled beta:  (61.861272704758946-2.945629828365233e-06j) . Residual of determinant:  2.3944776922638417e-10
#
#
#      --------------------  58/201: wavelength: 1.524225e-06  --------------------
#
# Scaled beta:  (61.8440120750874-3.0941213330921093e-06j) . Residual of determinant:  5.829586375534996e-12
#
#
#      --------------------  59/201: wavelength: 1.52465e-06  --------------------
#
# Scaled beta:  (61.826760612837454-3.281598024137136e-06j) . Residual of determinant:  7.507633852414667e-11
#
#
#      --------------------  60/201: wavelength: 1.525075e-06  --------------------
#
# Scaled beta:  (61.80951819452583-3.5161276635538157e-06j) . Residual of determinant:  2.34565471665516e-11
#
#
#      --------------------  61/201: wavelength: 1.5255e-06  --------------------
#
# Scaled beta:  (61.79228467168658-3.8087248223122935e-06j) . Residual of determinant:  8.295065460400645e-11
#
#
#      --------------------  62/201: wavelength: 1.5259250000000001e-06  --------------------
#
# Scaled beta:  (61.77505986163583-4.1745646926445235e-06j) . Residual of determinant:  1.838004277716156e-10
#
#
#      --------------------  63/201: wavelength: 1.52635e-06  --------------------
#
# Scaled beta:  (61.75784353430174-4.634858298045963e-06j) . Residual of determinant:  7.115499445249e-11
#
#
#      --------------------  64/201: wavelength: 1.526775e-06  --------------------
#
# Scaled beta:  (61.74063539291881-5.219825178946681e-06j) . Residual of determinant:  1.8995623836500023e-11
#
#
#      --------------------  65/201: wavelength: 1.5272e-06  --------------------
#
# Scaled beta:  (61.723435044886266-5.973553904545928e-06j) . Residual of determinant:  7.574183012488941e-11
#
#
#      --------------------  66/201: wavelength: 1.527625e-06  --------------------
#
# Scaled beta:  (61.70624195633145-6.962244669203302e-06j) . Residual of determinant:  2.109675645325181e-10
#
#
#      --------------------  67/201: wavelength: 1.5280500000000001e-06  --------------------
#
# Scaled beta:  (61.68905537861275-8.288801630867746e-06j) . Residual of determinant:  2.3211531213981105e-10
#
#
#      --------------------  68/201: wavelength: 1.528475e-06  --------------------
#
# Scaled beta:  (61.671874224242664-1.0120019861064172e-05j) . Residual of determinant:  6.133486478953437e-12
#
#
#      --------------------  69/201: wavelength: 1.5289e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.654696846553485-1.274044451472025e-05j) . Residual of determinant:  6.402843718054355e-11
#
#
#      --------------------  70/201: wavelength: 1.529325e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# Scaled beta:  (61.637520623783736-1.6667393637617133e-05j) . Residual of determinant:  9.129214623731372e-11
#
#
#      --------------------  71/201: wavelength: 1.52975e-06  --------------------
#
# Scaled beta:  (61.620341112604216-2.292081273688695e-05j) . Residual of determinant:  7.186714393835465e-11
#
#
#      --------------------  72/201: wavelength: 1.5301750000000001e-06  --------------------
#
# Scaled beta:  (61.6031501539933-3.37377948713732e-05j) . Residual of determinant:  3.6474247075154335e-11
#
#
#      --------------------  73/201: wavelength: 1.5306e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.58593108436139-5.479563142287192e-05j) . Residual of determinant:  9.342251858802652e-12
#
#
#      --------------------  74/201: wavelength: 1.531025e-06  --------------------
#
# Scaled beta:  (61.56864454814139-0.00010386591617505292j) . Residual of determinant:  1.3498373253882761e-11
#
#
#      --------------------  75/201: wavelength: 1.53145e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (61.5511777314623-0.0002571865669124896j) . Residual of determinant:  5.92064066524583e-13
#
#
#      --------------------  76/201: wavelength: 1.531875e-06  --------------------
#
# Scaled beta:  (61.53314618300449-0.0010117651936574245j) . Residual of determinant:  6.691920876431134e-13
#
#
#      --------------------  77/201: wavelength: 1.5323000000000001e-06  --------------------
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# scaling guess: 4
# scaling guess: 5
# scaling guess: 6
# scaling guess: 7
# scaling guess: 8
# scaling guess: 9
# scaling guess: 10
# scaling guess: 11
# scaling guess: 12
# scaling guess: 13
# scaling guess: 14
# scaling guess: 15
# scaling guess: 16
# scaling guess: 17
# Scaled beta:  (61.511070776644814-0.003420205370946762j) . Residual of determinant:  8.89157645570424e-15
#
#
#      --------------------  78/201: wavelength: 1.532725e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# scaling guess: 4
# scaling guess: 5
# scaling guess: 6
# scaling guess: 7
# scaling guess: 8
# scaling guess: 9
# scaling guess: 10
# scaling guess: 11
# scaling guess: 12
# scaling guess: 13
# scaling guess: 14
# scaling guess: 15
# scaling guess: 16
# scaling guess: 17
# scaling guess: 18
# scaling guess: 19
# scaling guess: 20
# scaling guess: 21
# scaling guess: 22
# scaling guess: 23
# scaling guess: 24
# Scaled beta:  (61.48519795426019-0.004137029577459832j) . Residual of determinant:  3.0759652678076047e-15
#
#
#      --------------------  79/201: wavelength: 1.53315e-06  --------------------
#
# Scaled beta:  (61.484664237437016-9.229482074779513e-05j) . Residual of determinant:  1.5191736364354912e-11
#
#
#      --------------------  80/201: wavelength: 1.533575e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.46742714869574-5.032984083068567e-05j) . Residual of determinant:  4.8546473363685415e-12
#
#
#      --------------------  81/201: wavelength: 1.534e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.450281481995695-3.169031896041409e-05j) . Residual of determinant:  7.0903924787394665e-12
#
#
#      --------------------  82/201: wavelength: 1.5344250000000001e-06  --------------------
#
# Scaled beta:  (61.43318420463358-2.188213047987016e-05j) . Residual of determinant:  5.5223820853856586e-11
#
#
#      --------------------  83/201: wavelength: 1.53485e-06  --------------------
#
# Scaled beta:  (61.4161178001396-1.6112228924437808e-05j) . Residual of determinant:  4.093880542313672e-11
#
#
#      --------------------  84/201: wavelength: 1.535275e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.399073838688764-1.2441023038980246e-05j) . Residual of determinant:  6.135024138146292e-11
#
#
#      --------------------  85/201: wavelength: 1.5357e-06  --------------------
#
# Scaled beta:  (61.38204777096652-9.966047220631999e-06j) . Residual of determinant:  7.705870284295627e-11
#
#
#      --------------------  86/201: wavelength: 1.536125e-06  --------------------
#
# Scaled beta:  (61.36503692718972-8.222246442127873e-06j) . Residual of determinant:  8.186972563535118e-12
#
#
#      --------------------  87/201: wavelength: 1.5365500000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.348039636504964-6.950552046888342e-06j) . Residual of determinant:  6.570566262832469e-11
#
#
#      --------------------  88/201: wavelength: 1.536975e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.33105479827029-5.99751601474693e-06j) . Residual of determinant:  9.774793758778431e-11
#
#
#      --------------------  89/201: wavelength: 1.5374e-06  --------------------
#
# Scaled beta:  (61.31408165629289-5.267644653861811e-06j) . Residual of determinant:  7.258165091897727e-11
#
#
#      --------------------  90/201: wavelength: 1.537825e-06  --------------------
#
# Scaled beta:  (61.29711967222291-4.699052675938689e-06j) . Residual of determinant:  1.1181995050062103e-10
#
#
#      --------------------  91/201: wavelength: 1.53825e-06  --------------------
#
# Scaled beta:  (61.28016845078608-4.25026515497756e-06j) . Residual of determinant:  4.3456048432832606e-11
#
#
#      --------------------  92/201: wavelength: 1.5386750000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.26322769367155-3.892698754768649e-06j) . Residual of determinant:  1.4697925968329811e-10
#
#
#      --------------------  93/201: wavelength: 1.5391e-06  --------------------
#
# Scaled beta:  (61.24629717001575-3.60619517935816e-06j) . Residual of determinant:  2.1021073575027017e-10
#
#
#      --------------------  94/201: wavelength: 1.539525e-06  --------------------
#
# Scaled beta:  (61.22937669688437-3.3762716642752322e-06j) . Residual of determinant:  3.0302460995553663e-12
#
#
#      --------------------  95/201: wavelength: 1.53995e-06  --------------------
#
# Scaled beta:  (61.21246612598358-3.1923764988630717e-06j) . Residual of determinant:  2.484090024743711e-11
#
#
#      --------------------  96/201: wavelength: 1.540375e-06  --------------------
#
# Scaled beta:  (61.19556533436349-3.0467538796255536e-06j) . Residual of determinant:  2.339137475385365e-10
#
#
#      --------------------  97/201: wavelength: 1.5408000000000001e-06  --------------------
#
# Scaled beta:  (61.178674217741225-2.933690213698196e-06j) . Residual of determinant:  1.999568337774473e-10
#
#
#      --------------------  98/201: wavelength: 1.541225e-06  --------------------
#
# Scaled beta:  (61.16179268557389-2.8490066168660836e-06j) . Residual of determinant:  9.55876608014791e-11
#
#
#      --------------------  99/201: wavelength: 1.54165e-06  --------------------
#
# Scaled beta:  (61.14492065731412-2.78971533168763e-06j) . Residual of determinant:  4.901746229764556e-10
#
#
#      --------------------  100/201: wavelength: 1.542075e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.128058059465246-2.753789166305958e-06j) . Residual of determinant:  1.5483979850366284e-10
#
#
#      --------------------  101/201: wavelength: 1.5425e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.111204823168435-2.740012323115292e-06j) . Residual of determinant:  1.9290879346960264e-10
#
#
#      --------------------  102/201: wavelength: 1.5429250000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.094360882125-2.747893361238789e-06j) . Residual of determinant:  2.337759137427698e-11
#
#
#      --------------------  103/201: wavelength: 1.54335e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.07752617069942-2.777629505225076e-06j) . Residual of determinant:  2.381471172759174e-10
#
#
#      --------------------  104/201: wavelength: 1.543775e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.06070062207105-2.8301179045566874e-06j) . Residual of determinant:  2.147442268634646e-10
#
#
#      --------------------  105/201: wavelength: 1.5442e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.04388416630824-2.907015009241444e-06j) . Residual of determinant:  8.795435051181247e-11
#
#
#      --------------------  106/201: wavelength: 1.544625e-06  --------------------
#
# Scaled beta:  (61.02707672822956-3.0108509815896906e-06j) . Residual of determinant:  3.858800055951221e-10
#
#
#      --------------------  107/201: wavelength: 1.5450500000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.010278224891856-3.145213080154364e-06j) . Residual of determinant:  6.734387044885779e-11
#
#
#      --------------------  108/201: wavelength: 1.545475e-06  --------------------
#
# Scaled beta:  (60.99348856249733-3.315021634675786e-06j) . Residual of determinant:  2.5238795335956315e-10
#
#
#      --------------------  109/201: wavelength: 1.5459e-06  --------------------
#
# Scaled beta:  (60.97670763243474-3.5269367287541887e-06j) . Residual of determinant:  4.944010488818437e-10
#
#
#      --------------------  110/201: wavelength: 1.546325e-06  --------------------
#
# Scaled beta:  (60.95993530604553-3.7899566162020846e-06j) . Residual of determinant:  3.8387706698912776e-10
#
#
#      --------------------  111/201: wavelength: 1.54675e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.9431714275049-4.116306564351041e-06j) . Residual of determinant:  2.379800664809072e-10
#
#
#      --------------------  112/201: wavelength: 1.5471750000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.92641580388216-4.522780926889948e-06j) . Residual of determinant:  3.6746588487576595e-11
#
#
#      --------------------  113/201: wavelength: 1.5476e-06  --------------------
#
# Scaled beta:  (60.9096681908977-5.032814134360614e-06j) . Residual of determinant:  3.0496674047521336e-11
#
#
#      --------------------  114/201: wavelength: 1.548025e-06  --------------------
# scaling guess: 1
# Scaled beta:  (60.89292827195779-5.67976237006794e-06j) . Residual of determinant:  7.500677673327464e-11
#
#
#      --------------------  115/201: wavelength: 1.54845e-06  --------------------
#
# Scaled beta:  (60.87619562638109-6.512269296318857e-06j) . Residual of determinant:  3.419383729641638e-10
#
#
#      --------------------  116/201: wavelength: 1.548875e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.85946967964863-7.603367809770804e-06j) . Residual of determinant:  1.5415660752190294e-11
#
#
#      --------------------  117/201: wavelength: 1.5493000000000001e-06  --------------------
#
# Scaled beta:  (60.842749622544126-9.06660091866816e-06j) . Residual of determinant:  1.0769054009955134e-11
#
#
#      --------------------  118/201: wavelength: 1.549725e-06  --------------------
#
# Scaled beta:  (60.826034273871144-1.1086076539524403e-05j) . Residual of determinant:  4.0176027257854755e-11
#
#
#      --------------------  119/201: wavelength: 1.55015e-06  --------------------
#
# Scaled beta:  (60.80932183494339-1.3976062703920372e-05j) . Residual of determinant:  7.774126429496183e-11
#
#
#      --------------------  120/201: wavelength: 1.550575e-06  --------------------
#
# Scaled beta:  (60.79260942189807-1.830842476168098e-05j) . Residual of determinant:  2.564454210066964e-11
#
#
#      --------------------  121/201: wavelength: 1.551e-06  --------------------
#
# Scaled beta:  (60.77589210190926-2.5212182102027998e-05j) . Residual of determinant:  3.954803892890271e-11
#
#
#      --------------------  122/201: wavelength: 1.5514250000000001e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (60.75916069672867-3.716919167719973e-05j) . Residual of determinant:  1.699366998846111e-12
#
#
#      --------------------  123/201: wavelength: 1.55185e-06  --------------------
#
# Scaled beta:  (60.742396060487295-6.050477076346458e-05j) . Residual of determinant:  2.7000723385746287e-12
#
#
#      --------------------  124/201: wavelength: 1.552275e-06  --------------------
#
# Scaled beta:  (60.72555109668842-0.00011522817392709433j) . Residual of determinant:  3.339681513412466e-13
#
#
#      --------------------  125/201: wavelength: 1.5527e-06  --------------------
#
# Scaled beta:  (60.70847498077614-0.0002908025685461857j) . Residual of determinant:  1.2259020664043334e-13
#
#
#      --------------------  126/201: wavelength: 1.553125e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# Scaled beta:  (60.69026066525085-0.0014218958259930986j) . Residual of determinant:  7.109841114203919e-14
#
#
#      --------------------  127/201: wavelength: 1.5535500000000001e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# scaling guess: 4
# scaling guess: 5
# scaling guess: 6
# scaling guess: 7
# scaling guess: 8
# scaling guess: 9
# scaling guess: 10
# scaling guess: 11
# scaling guess: 12
# scaling guess: 13
# scaling guess: 14
# scaling guess: 15
# scaling guess: 16
# scaling guess: 17
# scaling guess: 18
# scaling guess: 19
# scaling guess: 20
# Scaled beta:  (60.670835661801036-0.0055565996284673595j) . Residual of determinant:  7.481077225144306e-14
#
#
#      --------------------  128/201: wavelength: 1.553975e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# Scaled beta:  (60.660933919451345-0.00023421995127605286j) . Residual of determinant:  3.432291532752975e-12
#
#
#      --------------------  129/201: wavelength: 1.5544e-06  --------------------
#
# Scaled beta:  (60.64395481260684-0.0001000525455011506j) . Residual of determinant:  2.0268044350755263e-12
#
#
#      --------------------  130/201: wavelength: 1.554825e-06  --------------------
#
# Scaled beta:  (60.627185052692454-5.471724744277267e-05j) . Residual of determinant:  1.1058889584656827e-12
#
#
#      --------------------  131/201: wavelength: 1.55525e-06  --------------------
#
# Scaled beta:  (60.61050238249397-3.4490308370584754e-05j) . Residual of determinant:  1.989034758711264e-11
#
#
#      --------------------  132/201: wavelength: 1.5556750000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.593866735513245-2.3820314176418055e-05j) . Residual of determinant:  4.1136406357024025e-11
#
#
#      --------------------  133/201: wavelength: 1.5561e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.577261333179806-1.753353478822229e-05j) . Residual of determinant:  9.7949940169629e-12
#
#
#      --------------------  134/201: wavelength: 1.556525e-06  --------------------
#
# Scaled beta:  (60.56067796351308-1.3528912235534582e-05j) . Residual of determinant:  2.4246147497561277e-11
#
#
#      --------------------  135/201: wavelength: 1.55695e-06  --------------------
#
# Scaled beta:  (60.544112145026645-1.0826637066693062e-05j) . Residual of determinant:  4.069538303364647e-11
#
#
#      --------------------  136/201: wavelength: 1.557375e-06  --------------------
#
# Scaled beta:  (60.52756122688613-8.921007927838715e-06j) . Residual of determinant:  7.575559661155989e-11
#
#
#      --------------------  137/201: wavelength: 1.5578000000000001e-06  --------------------
#
# Scaled beta:  (60.51102354041835-7.529987817627462e-06j) . Residual of determinant:  1.6558371521362052e-10
#
#
#      --------------------  138/201: wavelength: 1.558225e-06  --------------------
#
# Scaled beta:  (60.4944979816147-6.486371234504066e-06j) . Residual of determinant:  1.413482862930204e-10
#
#
#      --------------------  139/201: wavelength: 1.55865e-06  --------------------
#
# Scaled beta:  (60.47798378950289-5.686020060333026e-06j) . Residual of determinant:  1.213817758147965e-10
#
#
#      --------------------  140/201: wavelength: 1.559075e-06  --------------------
#
# Scaled beta:  (60.46148042107423-5.0613944948035404e-06j) . Residual of determinant:  4.919025518043822e-10
#
#
#      --------------------  141/201: wavelength: 1.5595e-06  --------------------
#
# Scaled beta:  (60.44498747704903-4.5671908103932854e-06j) . Residual of determinant:  4.458373650074756e-10
#
#
#      --------------------  142/201: wavelength: 1.5599250000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.42850465590665-4.172152808652922e-06j) . Residual of determinant:  5.396366255342334e-12
#
#
#      --------------------  143/201: wavelength: 1.56035e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.412031724365086-3.854203649660325e-06j) . Residual of determinant:  2.4495182173839203e-10
#
#
#      --------------------  144/201: wavelength: 1.560775e-06  --------------------
#
# Scaled beta:  (60.39556849781251-3.5974465317208225e-06j) . Residual of determinant:  1.9602661161873594e-10
#
#
#      --------------------  145/201: wavelength: 1.5612e-06  --------------------
#
# Scaled beta:  (60.379114826963026-3.390259536512634e-06j) . Residual of determinant:  5.7495235981361066e-11
#
#
#      --------------------  146/201: wavelength: 1.561625e-06  --------------------
#
# Scaled beta:  (60.36267058851691-3.224053741192963e-06j) . Residual of determinant:  2.4418321946074224e-10
#
#
#      --------------------  147/201: wavelength: 1.5620500000000001e-06  --------------------
#
# Scaled beta:  (60.346235678459905-3.0924461912079e-06j) . Residual of determinant:  2.183696205765363e-11
#
#
#      --------------------  148/201: wavelength: 1.562475e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.32981000713493-2.9907000475501317e-06j) . Residual of determinant:  3.191575191234682e-10
#
#
#      --------------------  149/201: wavelength: 1.5629e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.31339349552156-2.9153417999344857e-06j) . Residual of determinant:  2.906994171654232e-10
#
#
#      --------------------  150/201: wavelength: 1.563325e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.29698607234352-2.8638994469215512e-06j) . Residual of determinant:  4.243667893160466e-10
#
#
#      --------------------  151/201: wavelength: 1.56375e-06  --------------------
#
# Scaled beta:  (60.28058767174097-2.834726304545089e-06j) . Residual of determinant:  2.304924245815226e-10
#
#
#      --------------------  152/201: wavelength: 1.5641750000000001e-06  --------------------
# Scaled beta:  (60.264198231318204-2.8268882462338293e-06j) . Residual of determinant:  2.956910003773082e-10
#
#
#      --------------------  153/201: wavelength: 1.5646e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.24781769042283-2.8401008983184605e-06j) . Residual of determinant:  5.704469578449039e-10
#
#
#      --------------------  154/201: wavelength: 1.565025e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.23144598853967-2.8747095188534172e-06j) . Residual of determinant:  4.754597705990897e-10
#
#
#      --------------------  155/201: wavelength: 1.56545e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.21508306369602-2.9317091882400255e-06j) . Residual of determinant:  5.448172272393095e-11
#
#
#      --------------------  156/201: wavelength: 1.565875e-06  --------------------
#
# Scaled beta:  (60.198728850775254-3.0128074158680987e-06j) . Residual of determinant:  3.522393352627124e-10
#
#
#      --------------------  157/201: wavelength: 1.5663000000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.18238327962741-3.1205360888426352e-06j) . Residual of determinant:  1.5421602987934928e-10
#
#
#      --------------------  158/201: wavelength: 1.566725e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.16604627284067-3.2584257081163307e-06j) . Residual of determinant:  2.3119895184260284e-10
#
#
#      --------------------  159/201: wavelength: 1.5671500000000001e-06  --------------------
#
# Scaled beta:  (60.149717742998725-3.431263228143021e-06j) . Residual of determinant:  2.3293991567417754e-10
#
#
#      --------------------  160/201: wavelength: 1.567575e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.133397589183346-3.6454673159623287e-06j) . Residual of determinant:  1.6082726229199185e-10
#
#
#      --------------------  161/201: wavelength: 1.568e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.11708569237906-3.909634427896483e-06j) . Residual of determinant:  3.101708172861118e-10
#
#
#      --------------------  162/201: wavelength: 1.5684250000000001e-06  --------------------
#
# Scaled beta:  (60.10078190927473-4.2353409211502505e-06j) . Residual of determinant:  3.29557829634735e-10
#
#
#      --------------------  163/201: wavelength: 1.56885e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.08448606369435-4.638339811056171e-06j) . Residual of determinant:  4.0571540987124714e-11
#
#
#      --------------------  164/201: wavelength: 1.5692750000000001e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (60.06819793446023-5.140383285817991e-06j) . Residual of determinant:  1.4603506343817977e-10
#
#
#      --------------------  165/201: wavelength: 1.5697e-06  --------------------
#
# Scaled beta:  (60.05191723776603-5.772067874151444e-06j) . Residual of determinant:  2.670384894429949e-11
#
#
#      --------------------  166/201: wavelength: 1.570125e-06  --------------------
#
# Scaled beta:  (60.03564360087175-6.577407612740328e-06j) . Residual of determinant:  7.825866790986087e-11
#
#
#      --------------------  167/201: wavelength: 1.5705500000000002e-06  --------------------
#
# Scaled beta:  (60.01937652164873-7.621439184665427e-06j) . Residual of determinant:  1.2098307659634247e-10
#
#
#      --------------------  168/201: wavelength: 1.570975e-06  --------------------
#
# Scaled beta:  (60.003115304195966-9.00338220077052e-06j) . Residual of determinant:  2.0276785856324098e-10
#
#
#      --------------------  169/201: wavelength: 1.5714000000000001e-06  --------------------
#
# Scaled beta:  (59.9868589522319-1.0880503694335252e-05j) . Residual of determinant:  6.760775000387305e-11
#
#
#      --------------------  170/201: wavelength: 1.571825e-06  --------------------
#
# Scaled beta:  (59.97060598412859-1.3513875316970865e-05j) . Residual of determinant:  5.817065063975922e-11
#
#
#      --------------------  171/201: wavelength: 1.57225e-06  --------------------
#
# Scaled beta:  (59.954354093504435-1.7362233365166435e-05j) . Residual of determinant:  1.1971167321254638e-10
#
#
#      --------------------  172/201: wavelength: 1.5726750000000002e-06  --------------------
#
# Scaled beta:  (59.938099482243985-2.329124166525581e-05j) . Residual of determinant:  3.068914152655575e-11
#
#
#      --------------------  173/201: wavelength: 1.5731e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.92183543246191-3.309193812748201e-05j) . Residual of determinant:  6.874502402875492e-12
#
#
#      --------------------  174/201: wavelength: 1.5735250000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.90554889295997-5.0954758138681446e-05j) . Residual of determinant:  3.175112398958952e-11
#
#
#      --------------------  175/201: wavelength: 1.57395e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (59.88921103687824-8.852096805085664e-05j) . Residual of determinant:  5.6108348583524266e-12
#
#
#      --------------------  176/201: wavelength: 1.574375e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# Scaled beta:  (59.87274532222126-0.00018744142922937147j) . Residual of determinant:  8.782756907145728e-13
#
#
#      --------------------  177/201: wavelength: 1.5748000000000002e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.85587851700398-0.0005688000603753162j) . Residual of determinant:  2.990637191244942e-14
#
#
#      --------------------  178/201: wavelength: 1.575225e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# scaling guess: 4
# scaling guess: 5
# scaling guess: 6
# scaling guess: 7
# scaling guess: 8
# scaling guess: 9
# scaling guess: 10
# Scaled beta:  (59.83973631036134-0.0036911604596681167j) . Residual of determinant:  6.062031104640583e-14
#
#
#      --------------------  179/201: wavelength: 1.5756500000000001e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# scaling guess: 4
# scaling guess: 5
# scaling guess: 6
# scaling guess: 7
# scaling guess: 8
# scaling guess: 9
# scaling guess: 10
# scaling guess: 11
# scaling guess: 12
# scaling guess: 13
# scaling guess: 14
# scaling guess: 15
# scaling guess: 16
# Scaled beta:  (59.82675554360842-0.0004405557852647157j) . Residual of determinant:  3.672981357668755e-12
#
#
#      --------------------  180/201: wavelength: 1.576075e-06  --------------------
#
# Scaled beta:  (59.80996671733641-0.0001577101434261088j) . Residual of determinant:  1.967149348381541e-12
#
#
#      --------------------  181/201: wavelength: 1.5765e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# Scaled beta:  (59.793566170938355-7.831538027812192e-05j) . Residual of determinant:  9.512925511133638e-12
#
#
#      --------------------  182/201: wavelength: 1.5769250000000002e-06  --------------------
#
# Scaled beta:  (59.77729905375775-4.6537555508855846e-05j) . Residual of determinant:  2.7461326619656288e-11
#
#
#      --------------------  183/201: wavelength: 1.57735e-06  --------------------
#
# Scaled beta:  (59.76109594968641-3.088960301183843e-05j) . Residual of determinant:  5.2103095212273586e-11
#
#
#      --------------------  184/201: wavelength: 1.5777750000000001e-06  --------------------
#
# Scaled beta:  (59.74493061900222-2.209287499509271e-05j) . Residual of determinant:  6.406707035946662e-11
#
#
#      --------------------  185/201: wavelength: 1.5782e-06  --------------------
#
# Scaled beta:  (59.728791063957736-1.6675827308399025e-05j) . Residual of determinant:  2.0136319956596224e-11
#
#
#      --------------------  186/201: wavelength: 1.578625e-06  --------------------
#
# Scaled beta:  (59.712671049414766-1.3111845757572004e-05j) . Residual of determinant:  1.1266822532659828e-10
#
#
#      --------------------  187/201: wavelength: 1.5790500000000002e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.69656702117311-1.064694382039667e-05j) . Residual of determinant:  5.100903358156112e-11
#
#
#      --------------------  188/201: wavelength: 1.579475e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (59.68047680618027-8.874741955368863e-06j) . Residual of determinant:  7.982577256876317e-11
#
#
#      --------------------  189/201: wavelength: 1.5799000000000001e-06  --------------------
#
# Scaled beta:  (59.664399000508375-7.560794114495479e-06j) . Residual of determinant:  1.8602207395850254e-10
#
#
#      --------------------  190/201: wavelength: 1.580325e-06  --------------------
# Scaled beta:  (59.64833265563175-6.56228215857637e-06j) . Residual of determinant:  1.1586891486400321e-10
#
#
#      --------------------  191/201: wavelength: 1.58075e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.632277106363816-5.7882536520954455e-06j) . Residual of determinant:  2.611784600457884e-10
#
#
#      --------------------  192/201: wavelength: 1.5811750000000002e-06  --------------------
#
# Scaled beta:  (59.6162318711349-5.178613997120933e-06j) . Residual of determinant:  6.493043751690543e-12
#
#
#      --------------------  193/201: wavelength: 1.5816e-06  --------------------
#
# Scaled beta:  (59.60019659147749-4.692413924824718e-06j) . Residual of determinant:  1.2043346190583592e-10
#
#
#      --------------------  194/201: wavelength: 1.5820250000000001e-06  --------------------
#
# Scaled beta:  (59.58417099384417-4.301017115172959e-06j) . Residual of determinant:  4.277037717541997e-10
#
#
#      --------------------  195/201: wavelength: 1.58245e-06  --------------------
#
# Scaled beta:  (59.56815486469186-3.983958042149374e-06j) . Residual of determinant:  7.433131825885625e-11
#
#
#      --------------------  196/201: wavelength: 1.582875e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.55214803373505-3.7263464090603095e-06j) . Residual of determinant:  5.056568211314819e-10
#
#
#      --------------------  197/201: wavelength: 1.5833000000000002e-06  --------------------
#
# Scaled beta:  (59.53615036238747-3.5171938741352813e-06j) . Residual of determinant:  2.4326650177321064e-10
#
#
#      --------------------  198/201: wavelength: 1.583725e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.52016173558679-3.3483089250785626e-06j) . Residual of determinant:  2.896345393645168e-10
#
#
#      --------------------  199/201: wavelength: 1.5841500000000001e-06  --------------------
#
# Scaled beta:  (59.50418205587611-3.213552187892708e-06j) . Residual of determinant:  5.86415084055092e-10
#
#
#      --------------------  200/201: wavelength: 1.584575e-06  --------------------
#
# Scaled beta:  (59.48821123901833-3.1083267642211697e-06j) . Residual of determinant:  5.178049835984667e-10
#
#
#      --------------------  201/201: wavelength: 1.585e-06  --------------------
#
# Scaled beta:  (59.47224921066551-3.0292260110042192e-06j) . Residual of determinant:  1.1117763826217565e-10

# %%
# %matplotlib notebook
plt.figure(figsize=(8,5))
plt.plot(wls, -betas1.imag, color='green', linewidth=.9)
plt.yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # We have double the resonators
#
# Makes sense that we might get more spikes: the resonators are interacting.  What about adding loss to polymer?

# %% [markdown]
# # Light Loss Polymer

# %%
n = 200
wls = np.linspace(1.5e-6, 1.585e-6, n+1)
betas2 = np.zeros_like(wls, dtype=complex)
outer = 'h2'
nu = 1

n_air = 1.00027717
n_glass = 1.4388164768221814
n_poly = 1.5 - .001j

# %%
for i, wl in enumerate(wls):
    print(5 * ' ' +  + 20 * '-' + '  ' + str(i+1) + '/' + str(n+1) + ': ' +
          'wavelength: ' +  str(wls[i]) + '  ' +  20 * '-' +5 * ' '+'\n')
    
    A = BraggExact(ts=ts, ns=ns , mats=mats,maxhs=maxhs, wl=wl)
    k_low = A.ks[0] * A.scale
    guess = np.array(.9999 * k_low)
    imag = 0
    flag = True
    reduce = 0

    while flag:
        try:
            x0 = np.array(guess + imag*1j)
            beta = newton(A.determinant, x0, args=(nu, outer), tol = 1e-17)
            if beta.real > k_low:
                print("Captured wrong mode, retrying.")
                raise RuntimeError
            elif beta.imag > 0:
                print("Positive imaginary part, retrying.")
                imag = -beta.imag
                guess *= 1/.999995
                raise RuntimeError
            else:
                print("Scaled beta: ", beta, ". Residual of determinant: ", 
                      abs(A.determinant(beta, nu, outer)), '\n\n' )
                imag = beta.imag
                flag=False
        except RuntimeError:
            guess *= .999995
            reduce += 1
            print("scaling guess: " + str(reduce), flush=True)
    betas2[i] = beta
# Out:
#      --------------------  1/201: wavelength: 1.5e-06  --------------------
#
# Scaled beta:  (62.843061753292396-2.7605048228521177e-05j) . Residual of determinant:  4.584695226855622e-10
#
#
#      --------------------  2/201: wavelength: 1.5004250000000001e-06  --------------------
#
# Scaled beta:  (62.82525088583829-2.7044987798011007e-05j) . Residual of determinant:  1.8385615933149885e-10
#
#
#      --------------------  3/201: wavelength: 1.50085e-06  --------------------
#
# Scaled beta:  (62.80745019240992-2.6719568269293526e-05j) . Residual of determinant:  1.9624033959196132e-11
#
#
#      --------------------  4/201: wavelength: 1.501275e-06  --------------------
#
# Scaled beta:  (62.78965961489635-2.6617698495196354e-05j) . Residual of determinant:  4.725659981979543e-10
#
#
#      --------------------  5/201: wavelength: 1.5017e-06  --------------------
#
# Scaled beta:  (62.77187909641972-2.6735613983894157e-05j) . Residual of determinant:  8.572132500980715e-10
#
#
#      --------------------  6/201: wavelength: 1.502125e-06  --------------------
#
# Scaled beta:  (62.754108580143985-2.7076606670752927e-05j) . Residual of determinant:  4.377537332388987e-10
#
#
#      --------------------  7/201: wavelength: 1.5025500000000001e-06  --------------------
#
# Scaled beta:  (62.73634800808943-2.765122169524823e-05j) . Residual of determinant:  1.168006047317158e-11
#
#
#      --------------------  8/201: wavelength: 1.502975e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (62.71859731990845-2.847794104945059e-05j) . Residual of determinant:  3.8230453443367023e-10
#
#
#      --------------------  9/201: wavelength: 1.5034e-06  --------------------
#
# Scaled beta:  (62.700856451582396-2.9584428114220263e-05j) . Residual of determinant:  5.509497640612068e-10
#
#
#      --------------------  10/201: wavelength: 1.503825e-06  --------------------
#
# Scaled beta:  (62.68312533400109-3.1009472954778125e-05j) . Residual of determinant:  1.8678809631670682e-10
#
#
#      --------------------  11/201: wavelength: 1.50425e-06  --------------------
#
# Scaled beta:  (62.66540389139694-3.2805867003267894e-05j) . Residual of determinant:  9.691650934485833e-11
#
#
#      --------------------  12/201: wavelength: 1.5046750000000001e-06  --------------------
#
# Scaled beta:  (62.64769203962885-3.504456347481558e-05j) . Residual of determinant:  2.0418903043202397e-10
#
#
#      --------------------  13/201: wavelength: 1.5051e-06  --------------------
#
# Scaled beta:  (62.62998968436425-3.782067104663697e-05j) . Residual of determinant:  2.898399437757621e-10
#
#
#      --------------------  14/201: wavelength: 1.505525e-06  --------------------
#
# Scaled beta:  (62.61229671932112-4.1262121338756275e-05j) . Residual of determinant:  2.105487213651322e-10
#
#
#      --------------------  15/201: wavelength: 1.50595e-06  --------------------
#
# Scaled beta:  (62.59461302497364-4.554230567808957e-05j) . Residual of determinant:  5.46847163562491e-10
#
#
#      --------------------  16/201: wavelength: 1.506375e-06  --------------------
#
# Scaled beta:  (62.57693846862819-5.0898685301437294e-05j) . Residual of determinant:  3.886549581252043e-11
#
#
#      --------------------  17/201: wavelength: 1.5068000000000001e-06  --------------------
#
# Scaled beta:  (62.55927290783117-5.7660471432191814e-05j) . Residual of determinant:  4.609739904613921e-11
#
#
#      --------------------  18/201: wavelength: 1.507225e-06  --------------------
#
# Scaled beta:  (62.54161620128056-6.62900937397788e-05j) . Residual of determinant:  1.9712101865162042e-11
#
#
#      --------------------  19/201: wavelength: 1.50765e-06  --------------------
#
# Scaled beta:  (62.52396823608135-7.744535040825583e-05j) . Residual of determinant:  1.3417893480857775e-10
#
#
#      --------------------  20/201: wavelength: 1.508075e-06  --------------------
#
# Scaled beta:  (62.50632899006232-9.207119921452176e-05j) . Residual of determinant:  4.677843948821153e-11
#
#
#      --------------------  21/201: wavelength: 1.5085e-06  --------------------
#
# Scaled beta:  (62.488698668550335-0.00011152880466801765j) . Residual of determinant:  8.92363006804893e-11
#
#
#      --------------------  22/201: wavelength: 1.5089250000000001e-06  --------------------
#
# Scaled beta:  (62.471077996454184-0.00013775246451612464j) . Residual of determinant:  1.2981605330315295e-11
#
#
#      --------------------  23/201: wavelength: 1.50935e-06  --------------------
#
# Scaled beta:  (62.4534688191561-0.0001733529380365625j) . Residual of determinant:  9.33568877664486e-11
#
#
#      --------------------  24/201: wavelength: 1.509775e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# Scaled beta:  (62.4358752404243-0.0002213499005580922j) . Residual of determinant:  9.07222845995906e-13
#
#
#      --------------------  25/201: wavelength: 1.5102e-06  --------------------
#
# Scaled beta:  (62.41830534389979-0.00028361357707178966j) . Residual of determinant:  5.0139588946359175e-11
#
#
#      --------------------  26/201: wavelength: 1.510625e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (62.40077211032517-0.00035626002889620445j) . Residual of determinant:  2.7057150581126186e-11
#
#
#      --------------------  27/201: wavelength: 1.5110500000000001e-06  --------------------
#
# Scaled beta:  (62.383288118567684-0.00042198370156284033j) . Residual of determinant:  1.5018225722101407e-11
#
#
#      --------------------  28/201: wavelength: 1.511475e-06  --------------------
#
# Scaled beta:  (62.36584838147612-0.00045027950622918134j) . Residual of determinant:  1.0177114289107421e-11
#
#
#      --------------------  29/201: wavelength: 1.5119e-06  --------------------
#
# Scaled beta:  (62.34841928366768-0.0004225647890857568j) . Residual of determinant:  8.35545587265031e-13
#
#
#      --------------------  30/201: wavelength: 1.512325e-06  --------------------
#
# Scaled beta:  (62.33096557847818-0.0003559505024469483j) . Residual of determinant:  2.298697823493831e-11
#
#
#      --------------------  31/201: wavelength: 1.51275e-06  --------------------
#
# Scaled beta:  (62.313481138639865-0.00028229967722086827j) . Residual of determinant:  3.784426097149872e-11
#
#
#      --------------------  32/201: wavelength: 1.5131750000000001e-06  --------------------
#
# Scaled beta:  (62.29597933240012-0.0002198040145558039j) . Residual of determinant:  2.8317934349259444e-11
#
#
#      --------------------  33/201: wavelength: 1.5136e-06  --------------------
#
# Scaled beta:  (62.27847379831796-0.00017211177558946656j) . Residual of determinant:  2.8562805392021543e-11
#
#
#      --------------------  34/201: wavelength: 1.514025e-06  --------------------
#
# Scaled beta:  (62.26097272620091-0.0001369793838463846j) . Residual of determinant:  3.3555344492048806e-11
#
#
#      --------------------  35/201: wavelength: 1.51445e-06  --------------------
#
# Scaled beta:  (62.24348012213292-0.00011119628726051343j) . Residual of determinant:  4.634738531095414e-11
#
#
#      --------------------  36/201: wavelength: 1.514875e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (62.22599772524035-9.209337965779487e-05j) . Residual of determinant:  1.7338615922332976e-10
#
#
#      --------------------  37/201: wavelength: 1.5153000000000001e-06  --------------------
#
# Scaled beta:  (62.20852618947053-7.773477818780538e-05j) . Residual of determinant:  1.4830051421353243e-10
#
#
#      --------------------  38/201: wavelength: 1.515725e-06  --------------------
#
# Scaled beta:  (62.19106567991213-6.677497500922358e-05j) . Residual of determinant:  1.0956138455584775e-10
#
#
#      --------------------  39/201: wavelength: 1.51615e-06  --------------------
#
# Scaled beta:  (62.17361615353612-5.828656219370964e-05j) . Residual of determinant:  1.9257942601628544e-10
#
#
#      --------------------  40/201: wavelength: 1.516575e-06  --------------------
#
# Scaled beta:  (62.15617748750121-5.1626521458408094e-05j) . Residual of determinant:  1.8067082234747348e-11
#
#
#      --------------------  41/201: wavelength: 1.517e-06  --------------------
#
# Scaled beta:  (62.13874953636919-4.634370589472893e-05j) . Residual of determinant:  1.4436738028358466e-10
#
#
#      --------------------  42/201: wavelength: 1.5174250000000001e-06  --------------------
#
# Scaled beta:  (62.12133215652476-4.211716549132319e-05j) . Residual of determinant:  1.1890901014181083e-10
#
#
#      --------------------  43/201: wavelength: 1.51785e-06  --------------------
# Scaled beta:  (62.103925215568914-3.871537740001963e-05j) . Residual of determinant:  1.3703214572025837e-11
#
#
#      --------------------  44/201: wavelength: 1.518275e-06  --------------------
#
# Scaled beta:  (62.08652859493328-3.5969184972381176e-05j) . Residual of determinant:  9.687176544311652e-11
#
#
#      --------------------  45/201: wavelength: 1.5187e-06  --------------------
#
# Scaled beta:  (62.06914218955236-3.3753663703838464e-05j) . Residual of determinant:  2.8706835655458146e-10
#
#
#      --------------------  46/201: wavelength: 1.519125e-06  --------------------
#
# Scaled beta:  (62.05176590637198-3.197582905531392e-05j) . Residual of determinant:  9.06164608611081e-11
#
#
#      --------------------  47/201: wavelength: 1.5195500000000001e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (62.034399662503894-3.056621014677955e-05j) . Residual of determinant:  1.6205982952398198e-11
#
#
#      --------------------  48/201: wavelength: 1.519975e-06  --------------------
#
# Scaled beta:  (62.01704338337828-2.94730202964633e-05j) . Residual of determinant:  1.0654373949419923e-10
#
#
#      --------------------  49/201: wavelength: 1.5204e-06  --------------------
#
# Scaled beta:  (61.99969700102911-2.865810410035552e-05j) . Residual of determinant:  2.0915056910429882e-10
#
#
#      --------------------  50/201: wavelength: 1.520825e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.982360452546935-2.8094127431537394e-05j) . Residual of determinant:  7.181734207662874e-11
#
#
#      --------------------  51/201: wavelength: 1.52125e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.965033678687384-2.7762662554640003e-05j) . Residual of determinant:  1.4874602251249153e-10
#
#
#      --------------------  52/201: wavelength: 1.5216750000000001e-06  --------------------
#
# Scaled beta:  (61.94771662260513-2.7652943776491757e-05j) . Residual of determinant:  1.2091656658197936e-10
#
#
#      --------------------  53/201: wavelength: 1.5221e-06  --------------------
#
# Scaled beta:  (61.93040922867482-2.7761153763746206e-05j) . Residual of determinant:  2.69386754289266e-10
#
#
#      --------------------  54/201: wavelength: 1.522525e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.913111441358936-2.80901623478404e-05j) . Residual of determinant:  2.266588493639251e-10
#
#
#      --------------------  55/201: wavelength: 1.52295e-06  --------------------
#
# Scaled beta:  (61.895823204081786-2.8649688812594934e-05j) . Residual of determinant:  2.0793778710167922e-10
#
#
#      --------------------  56/201: wavelength: 1.523375e-06  --------------------
#
# Scaled beta:  (61.87854445806933-2.9456903166241784e-05j) . Residual of determinant:  8.325747326624204e-11
#
#
#      --------------------  57/201: wavelength: 1.5238000000000001e-06  --------------------
#
# Scaled beta:  (61.86127514111501-3.053752857708484e-05j) . Residual of determinant:  9.146418331837393e-11
#
#
#      --------------------  58/201: wavelength: 1.524225e-06  --------------------
#
# Scaled beta:  (61.844015186233925-3.1927563263586944e-05j) . Residual of determinant:  1.7373463475631264e-10
#
#
#      --------------------  59/201: wavelength: 1.52465e-06  --------------------
#
# Scaled beta:  (61.826764520173846-3.367581477220178e-05j) . Residual of determinant:  6.818557350589378e-11
#
#
#      --------------------  60/201: wavelength: 1.525075e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (61.80952306176739-3.584754576389056e-05j) . Residual of determinant:  2.1576666476499525e-10
#
#
#      --------------------  61/201: wavelength: 1.5255e-06  --------------------
#
# Scaled beta:  (61.792290720145644-3.852968768166643e-05j) . Residual of determinant:  1.2978085845685698e-10
#
#
#      --------------------  62/201: wavelength: 1.5259250000000001e-06  --------------------
#
# Scaled beta:  (61.77506739291367-4.1838317595166666e-05j) . Residual of determinant:  1.3984827684471194e-11
#
#
#      --------------------  63/201: wavelength: 1.52635e-06  --------------------
#
# Scaled beta:  (61.75785296455667-4.5929462116043694e-05j) . Residual of determinant:  2.032117268562495e-10
#
#
#      --------------------  64/201: wavelength: 1.526775e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.74064730569685-5.101486517044683e-05j) . Residual of determinant:  8.243594210640723e-11
#
#
#      --------------------  65/201: wavelength: 1.5272e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.72345027455026-5.7385244602461224e-05j) . Residual of determinant:  1.4715987646993241e-10
#
#
#      --------------------  66/201: wavelength: 1.527625e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.70626172344789-6.544491283730948e-05j) . Residual of determinant:  1.2499820010759219e-10
#
#
#      --------------------  67/201: wavelength: 1.5280500000000001e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (61.6890815164562-7.576357732368543e-05j) . Residual of determinant:  2.086799188160656e-10
#
#
#      --------------------  68/201: wavelength: 1.528475e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.67190957080066-8.915351740781141e-05j) . Residual of determinant:  9.650252880978716e-12
#
#
#      --------------------  69/201: wavelength: 1.5289e-06  --------------------
#
# Scaled beta:  (61.65474594882723-0.00010678176632988828j) . Residual of determinant:  8.801743994987125e-12
#
#
#      --------------------  70/201: wavelength: 1.529325e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.637591056227635-0.00013032155293014617j) . Residual of determinant:  7.269802495691924e-11
#
#
#      --------------------  71/201: wavelength: 1.52975e-06  --------------------
#
# Scaled beta:  (61.62044605856725-0.00016211468611567912j) . Residual of determinant:  4.391082319174266e-11
#
#
#      --------------------  72/201: wavelength: 1.5301750000000001e-06  --------------------
#
# Scaled beta:  (61.60331371802751-0.00020519394177907435j) . Residual of determinant:  1.374503109699993e-11
#
#
#      --------------------  73/201: wavelength: 1.5306e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.586199898589335-0.00026264036688805153j) . Residual of determinant:  2.632259659156103e-11
#
#
#      --------------------  74/201: wavelength: 1.531025e-06  --------------------
#
# Scaled beta:  (61.56911550407348-0.000334889149804937j) . Residual of determinant:  2.529400686731675e-12
#
#
#      --------------------  75/201: wavelength: 1.53145e-06  --------------------
#
# Scaled beta:  (61.552076012625086-0.00041290576798879715j) . Residual of determinant:  3.3150535524683616e-12
#
#
#      --------------------  76/201: wavelength: 1.531875e-06  --------------------
#
# Scaled beta:  (61.535090374764074-0.0004701259002563732j) . Residual of determinant:  4.728521505186685e-12
#
#
#      --------------------  77/201: wavelength: 1.5323000000000001e-06  --------------------
#
# Scaled beta:  (61.51813852092046-0.0004732078865331574j) . Residual of determinant:  1.9240995345720242e-11
#
#
#      --------------------  78/201: wavelength: 1.532725e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# Scaled beta:  (61.50117596665475-0.00041948324040994695j) . Residual of determinant:  1.957826741934241e-11
#
#
#      --------------------  79/201: wavelength: 1.53315e-06  --------------------
#
# Scaled beta:  (61.484178196084436-0.000341255192263577j) . Residual of determinant:  2.479396791323271e-11
#
#
#      --------------------  80/201: wavelength: 1.533575e-06  --------------------
#
# Scaled beta:  (61.46715255368585-0.00026756083663805687j) . Residual of determinant:  3.975514386860224e-12
#
#
#      --------------------  81/201: wavelength: 1.534e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (61.45011519581864-0.00020884240180057303j) . Residual of determinant:  3.3697228840396264e-11
#
#
#      --------------------  82/201: wavelength: 1.5344250000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.43307774061245-0.00016489978592107448j) . Residual of determinant:  5.03318159889245e-11
#
#
#      --------------------  83/201: wavelength: 1.53485e-06  --------------------
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (61.416046392361274-0.00013255030361882168j) . Residual of determinant:  8.521770977148701e-11
#
#
#      --------------------  84/201: wavelength: 1.535275e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.399024039763255-0.00010864489448069101j) . Residual of determinant:  1.0441527646546382e-11
#
#
#      --------------------  85/201: wavelength: 1.5357e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.38201188944145-9.0765299157606e-05j) . Residual of determinant:  1.0936636665042933e-10
#
#
#      --------------------  86/201: wavelength: 1.536125e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.3650103584107-7.719368979477286e-05j) . Residual of determinant:  1.4118839962831338e-10
#
#
#      --------------------  87/201: wavelength: 1.5365500000000001e-06  --------------------
#
# Scaled beta:  (61.34801951094064-6.67374808380193e-05j) . Residual of determinant:  7.276698357611343e-11
#
#
#      --------------------  88/201: wavelength: 1.536975e-06  --------------------
#
# Scaled beta:  (61.3310392636456-5.856944764922715e-05j) . Residual of determinant:  1.3820651779553963e-11
#
#
#      --------------------  89/201: wavelength: 1.5374e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.314069479611675-5.211080400547827e-05j) . Residual of determinant:  2.1801420699208787e-10
#
#
#      --------------------  90/201: wavelength: 1.537825e-06  --------------------
#
# Scaled beta:  (61.29711001042182-4.6951462716945534e-05j) . Residual of determinant:  3.474083125125742e-11
#
#
#      --------------------  91/201: wavelength: 1.53825e-06  --------------------
#
# Scaled beta:  (61.28016071388506-4.279684375482285e-05j) . Residual of determinant:  1.8753609855657994e-11
#
#
#      --------------------  92/201: wavelength: 1.5386750000000001e-06  --------------------
#
# Scaled beta:  (61.26322146053017-3.9432479587498124e-05j) . Residual of determinant:  4.2293189669470455e-10
#
#
#      --------------------  93/201: wavelength: 1.5391e-06  --------------------
#
# Scaled beta:  (61.246292135012084-3.670031240971766e-05j) . Residual of determinant:  3.7288022201453113e-10
#
#
#      --------------------  94/201: wavelength: 1.539525e-06  --------------------
#
# Scaled beta:  (61.22937263532779-3.448265721421362e-05j) . Residual of determinant:  1.286950954519714e-10
#
#
#      --------------------  95/201: wavelength: 1.53995e-06  --------------------
#
# Scaled beta:  (61.212462871197175-3.2691225850158436e-05j) . Residual of determinant:  3.469580833527548e-11
#
#
#      --------------------  96/201: wavelength: 1.540375e-06  --------------------
#
# Scaled beta:  (61.19556276222871-3.125953163731305e-05j) . Residual of determinant:  2.3221338538719805e-10
#
#
#      --------------------  97/201: wavelength: 1.5408000000000001e-06  --------------------
#
# Scaled beta:  (61.178672236136585-3.013758564718071e-05j) . Residual of determinant:  1.7884547256736942e-10
#
#
#      --------------------  98/201: wavelength: 1.541225e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.16179122710811-2.9288173952882472e-05j) . Residual of determinant:  3.449887016208749e-11
#
#
#      --------------------  99/201: wavelength: 1.54165e-06  --------------------
#
# Scaled beta:  (61.14491967434162-2.868424882235814e-05j) . Residual of determinant:  1.3739083515856983e-10
#
#
#      --------------------  100/201: wavelength: 1.542075e-06  --------------------
#
# Scaled beta:  (61.128057520739354-2.8307126078792075e-05j) . Residual of determinant:  8.741934606814835e-10
#
#
#      --------------------  101/201: wavelength: 1.5425e-06  --------------------
#
# Scaled beta:  (61.11120471172527-2.8145287181720915e-05j) . Residual of determinant:  4.914993071766165e-10
#
#
#      --------------------  102/201: wavelength: 1.5429250000000001e-06  --------------------
#
# Scaled beta:  (61.094361194152576-2.8193657927288062e-05j) . Residual of determinant:  4.54481374688944e-12
#
#
#      --------------------  103/201: wavelength: 1.54335e-06  --------------------
#
# Scaled beta:  (61.07752691526377-2.8453288911969933e-05j) . Residual of determinant:  2.579208719024289e-10
#
#
#      --------------------  104/201: wavelength: 1.543775e-06  --------------------
#
# Scaled beta:  (61.06070182166742-2.8931404773884988e-05j) . Residual of determinant:  7.49102645583194e-11
#
#
#      --------------------  105/201: wavelength: 1.5442e-06  --------------------
#
# Scaled beta:  (61.04388585829513-2.9641826127121914e-05j) . Residual of determinant:  4.9253316155359595e-11
#
#
#      --------------------  106/201: wavelength: 1.544625e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (61.02707896730292-3.060580546045892e-05j) . Residual of determinant:  2.234934845576602e-10
#
#
#      --------------------  107/201: wavelength: 1.5450500000000001e-06  --------------------
#
# Scaled beta:  (61.01028108688272-3.185336155720168e-05j) . Residual of determinant:  1.205068315513954e-10
#
#
#      --------------------  108/201: wavelength: 1.545475e-06  --------------------
#
# Scaled beta:  (60.99349214995161-3.342525282784909e-05j) . Residual of determinant:  1.5488842796528022e-10
#
#
#      --------------------  109/201: wavelength: 1.5459e-06  --------------------
#
# Scaled beta:  (60.976712082695755-3.537580740906442e-05j) . Residual of determinant:  1.0685539709022659e-10
#
#
#      --------------------  110/201: wavelength: 1.546325e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (60.95994080296574-3.7776940414772976e-05j) . Residual of determinant:  2.3721274011542877e-10
#
#
#      --------------------  111/201: wavelength: 1.54675e-06  --------------------
#
# Scaled beta:  (60.94317821856527-4.072385701361832e-05j) . Residual of determinant:  4.371602842659456e-10
#
#
#      --------------------  112/201: wavelength: 1.5471750000000001e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (60.92642422557186-4.434319642941457e-05j) . Residual of determinant:  2.371887735333668e-10
#
#
#      --------------------  113/201: wavelength: 1.5476e-06  --------------------
#
# Scaled beta:  (60.909678707029194-4.880476716349168e-05j) . Residual of determinant:  5.447237404195334e-11
#
#
#      --------------------  114/201: wavelength: 1.548025e-06  --------------------
#
# Scaled beta:  (60.892941532763096-5.433863539536346e-05j) . Residual of determinant:  2.146788327994737e-10
#
#
#      --------------------  115/201: wavelength: 1.54845e-06  --------------------
#
# Scaled beta:  (60.876212561922664-6.126026907650124e-05j) . Residual of determinant:  1.0202039873553143e-10
#
#
#      --------------------  116/201: wavelength: 1.548875e-06  --------------------
#
# Scaled beta:  (60.85949165159806-7.00078487769371e-05j) . Residual of determinant:  9.238688953090718e-11
#
#
#      --------------------  117/201: wavelength: 1.5493000000000001e-06  --------------------
#
# Scaled beta:  (60.84277867850523-8.119781923345385e-05j) . Residual of determinant:  4.524010491016871e-11
#
#
#      --------------------  118/201: wavelength: 1.549725e-06  --------------------
#
# Scaled beta:  (60.82607358833096-9.570696857253943e-05j) . Residual of determinant:  1.3732148127272297e-10
#
#
#      --------------------  119/201: wavelength: 1.55015e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.80937650318957-0.00011478988784454169j) . Residual of determinant:  1.700958846481257e-11
#
#
#      --------------------  120/201: wavelength: 1.550575e-06  --------------------
#
# Scaled beta:  (60.79268794996815-0.00014023214482921485j) . Residual of determinant:  3.4610127941222485e-11
#
#
#      --------------------  121/201: wavelength: 1.551e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# Scaled beta:  (60.776009333319166-0.00017449688176071466j) . Residual of determinant:  7.584243598407309e-11
#
#
#      --------------------  122/201: wavelength: 1.5514250000000001e-06  --------------------
#
# Scaled beta:  (60.75934386603225-0.00022067108801805297j) . Residual of determinant:  8.444080978026177e-11
#
#
#      --------------------  123/201: wavelength: 1.55185e-06  --------------------
# Scaled beta:  (60.742698169064305-0.00028157760676357285j) . Residual of determinant:  7.1194459705044434e-12
#
#
#      --------------------  124/201: wavelength: 1.552275e-06  --------------------
#
# Scaled beta:  (60.72608403234071-0.0003565073644456625j) . Residual of determinant:  2.6758919624750486e-12
#
#
#      --------------------  125/201: wavelength: 1.5527e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.709516674192926-0.0004338474439819649j) . Residual of determinant:  6.9861010650188095e-12
#
#
#      --------------------  126/201: wavelength: 1.553125e-06  --------------------
#
# Scaled beta:  (60.69300130468642-0.0004849604062319548j) . Residual of determinant:  6.2391818343024024e-12
#
#
#      --------------------  127/201: wavelength: 1.5535500000000001e-06  --------------------
#
# Scaled beta:  (60.676513142389155-0.00048007207178268224j) . Residual of determinant:  8.73682359244402e-12
#
#
#      --------------------  128/201: wavelength: 1.553975e-06  --------------------
#
# Scaled beta:  (60.660009854604915-0.0004224368456765987j) . Residual of determinant:  2.168396254538691e-12
#
#
#      --------------------  129/201: wavelength: 1.5544e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.64347193585907-0.0003440715360526311j) . Residual of determinant:  1.702021534365921e-11
#
#
#      --------------------  130/201: wavelength: 1.554825e-06  --------------------
#
# Scaled beta:  (60.626907742282924-0.0002711126368998588j) . Residual of determinant:  4.907162012223359e-11
#
#
#      --------------------  131/201: wavelength: 1.55525e-06  --------------------
#
# Scaled beta:  (60.61033245929914-0.00021277297907001027j) . Residual of determinant:  3.697776258066881e-11
#
#
#      --------------------  132/201: wavelength: 1.5556750000000001e-06  --------------------
#
# Scaled beta:  (60.593756975437934-0.00016879108041779526j) . Residual of determinant:  1.4838775207402298e-10
#
#
#      --------------------  133/201: wavelength: 1.5561e-06  --------------------
#
# Scaled beta:  (60.577187214090664-0.00013616953794769572j) . Residual of determinant:  1.2527055811828719e-10
#
#
#      --------------------  134/201: wavelength: 1.556525e-06  --------------------
#
# Scaled beta:  (60.560625998932146-0.00011190340893292439j) . Residual of determinant:  2.1573973109455638e-12
#
#
#      --------------------  135/201: wavelength: 1.55695e-06  --------------------
#
# Scaled beta:  (60.54407454288197-9.365181726300029e-05j) . Residual of determinant:  2.651757568190006e-11
#
#
#      --------------------  136/201: wavelength: 1.557375e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.52753328457423-7.973138374693772e-05j) . Residual of determinant:  1.500580587080988e-11
#
#
#      --------------------  137/201: wavelength: 1.5578000000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.511002308228335-6.896158237031296e-05j) . Residual of determinant:  1.1993257862034575e-10
#
#
#      --------------------  138/201: wavelength: 1.558225e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.494481545288-6.051674102180673e-05j) . Residual of determinant:  8.04536276050377e-11
#
#
#      --------------------  139/201: wavelength: 1.55865e-06  --------------------
#
# Scaled beta:  (60.477970869018534-5.381517164877147e-05j) . Residual of determinant:  1.731242082490141e-10
#
#
#      --------------------  140/201: wavelength: 1.559075e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.461470137770505-4.8442319255744184e-05j) . Residual of determinant:  1.8499447369350612e-10
#
#
#      --------------------  141/201: wavelength: 1.5595e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.4449792138275-4.4098869507752525e-05j) . Residual of determinant:  2.9604234000090636e-10
#
#
#      --------------------  142/201: wavelength: 1.5599250000000001e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (60.42849797073145-4.056588564837406e-05j) . Residual of determinant:  7.746921376626076e-11
#
#
#      --------------------  143/201: wavelength: 1.56035e-06  --------------------
#
# Scaled beta:  (60.41202629526524-3.768127676952206e-05j) . Residual of determinant:  2.640397236260277e-10
#
#
#      --------------------  144/201: wavelength: 1.560775e-06  --------------------
#
# Scaled beta:  (60.39556408705799-3.532376857178474e-05j) . Residual of determinant:  1.8243403935185034e-10
#
#
#      --------------------  145/201: wavelength: 1.5612e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.379111257228985-3.340186521509232e-05j) . Residual of determinant:  6.95657626572821e-11
#
#
#      --------------------  146/201: wavelength: 1.561625e-06  --------------------
#
# Scaled beta:  (60.362667726734145-3.184616461463276e-05j) . Residual of determinant:  4.059615268188281e-10
#
#
#      --------------------  147/201: wavelength: 1.5620500000000001e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.34623342471319-3.0603956372648466e-05j) . Residual of determinant:  1.7234525880381043e-10
#
#
#      --------------------  148/201: wavelength: 1.562475e-06  --------------------
#
# Scaled beta:  (60.32980828695676-2.9635397590398874e-05j) . Residual of determinant:  6.282545156979241e-10
#
#
#      --------------------  149/201: wavelength: 1.5629e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (60.31339225452843-2.8910799328686512e-05j) . Residual of determinant:  7.382294673131621e-11
#
#
#      --------------------  150/201: wavelength: 1.563325e-06  --------------------
#
# Scaled beta:  (60.2969852725364-2.840871229858421e-05j) . Residual of determinant:  4.6165772723655326e-10
#
#
#      --------------------  151/201: wavelength: 1.56375e-06  --------------------
#
# Scaled beta:  (60.280587289032255-2.8114604284117705e-05j) . Residual of determinant:  3.286313692809658e-11
#
#
#      --------------------  152/201: wavelength: 1.5641750000000001e-06  --------------------
#
# Scaled beta:  (60.26419825400789-2.8019992811250563e-05j) . Residual of determinant:  3.2113883124861466e-10
#
#
#      --------------------  153/201: wavelength: 1.5646e-06  --------------------
#
# Scaled beta:  (60.24781811845988-2.8121946918071956e-05j) . Residual of determinant:  1.9538307351046782e-10
#
#
#      --------------------  154/201: wavelength: 1.565025e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.231446833489784-2.842290966679267e-05j) . Residual of determinant:  3.4239345065767673e-10
#
#
#      --------------------  155/201: wavelength: 1.56545e-06  --------------------
#
# Scaled beta:  (60.21508434941052-2.8930823953998728e-05j) . Residual of determinant:  1.3357131905986127e-11
#
#
#      --------------------  156/201: wavelength: 1.565875e-06  --------------------
#
# Scaled beta:  (60.198730614828165-2.9659572599753726e-05j) . Residual of determinant:  4.34948138944278e-10
#
#
#      --------------------  157/201: wavelength: 1.5663000000000001e-06  --------------------
#
# Scaled beta:  (60.18238557566952-3.062977353868446e-05j) . Residual of determinant:  2.9583512294058224e-11
#
#
#      --------------------  158/201: wavelength: 1.566725e-06  --------------------
#
# Scaled beta:  (60.16604917412617-3.187000634170474e-05j) . Residual of determinant:  1.1366378293511364e-10
#
#
#      --------------------  159/201: wavelength: 1.5671500000000001e-06  --------------------
#
# Scaled beta:  (60.149721347488075-3.3418592429543035e-05j) . Residual of determinant:  6.363211676340306e-10
#
#
#      --------------------  160/201: wavelength: 1.567575e-06  --------------------
#
# Scaled beta:  (60.13340202684671-3.53261153555347e-05j) . Residual of determinant:  1.4011401901291302e-11
#
#
#      --------------------  161/201: wavelength: 1.568e-06  --------------------
#
# Scaled beta:  (60.1170911356636-3.7658960017819266e-05j) . Residual of determinant:  1.4348185650196165e-11
#
#
#      --------------------  162/201: wavelength: 1.5684250000000001e-06  --------------------
#
# Scaled beta:  (60.100788588236156-4.0504286780540664e-05j) . Residual of determinant:  8.370299736559492e-11
#
#
#      --------------------  163/201: wavelength: 1.56885e-06  --------------------
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (60.08449428816809-4.397706330169228e-05j) . Residual of determinant:  1.7652344059399333e-10
#
#
#      --------------------  164/201: wavelength: 1.5692750000000001e-06  --------------------
#
# Scaled beta:  (60.068208127106125-4.8230092231705716e-05j) . Residual of determinant:  2.399804633321567e-10
#
#
#      --------------------  165/201: wavelength: 1.5697e-06  --------------------
#
# Scaled beta:  (60.05192998431778-5.3468456051041586e-05j) . Residual of determinant:  1.9026113476734321e-10
#
#
#      --------------------  166/201: wavelength: 1.570125e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (60.035659728316396-5.997053706830208e-05j) . Residual of determinant:  6.980284520769462e-11
#
#
#      --------------------  167/201: wavelength: 1.5705500000000002e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (60.019397223018835-6.811887088970497e-05j) . Residual of determinant:  3.14283774208576e-10
#
#
#      --------------------  168/201: wavelength: 1.570975e-06  --------------------
#
# Scaled beta:  (60.00314234352849-7.844564474752842e-05j) . Residual of determinant:  1.2000297201214974e-10
#
#
#      --------------------  169/201: wavelength: 1.5714000000000001e-06  --------------------
#
# Scaled beta:  (59.98689501198115-9.169953148884906e-05j) . Residual of determinant:  1.0681411435071729e-10
#
#
#      --------------------  170/201: wavelength: 1.571825e-06  --------------------
#
# Scaled beta:  (59.970655274856824-0.00010894172479641413j) . Residual of determinant:  8.81668705133495e-11
#
#
#      --------------------  171/201: wavelength: 1.57225e-06  --------------------
#
# Scaled beta:  (59.954423465327835-0.00013167534909700279j) . Residual of determinant:  1.5641665412034057e-10
#
#
#      --------------------  172/201: wavelength: 1.5726750000000002e-06  --------------------
#
# Scaled beta:  (59.93820053676778-0.0001619898202458604j) . Residual of determinant:  6.477414599249652e-11
#
#
#      --------------------  173/201: wavelength: 1.5731e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (59.92198872327299-0.00020261780171205494j) . Residual of determinant:  8.954412073421885e-12
#
#
#      --------------------  174/201: wavelength: 1.5735250000000001e-06  --------------------
#
# Scaled beta:  (59.90579273945142-0.00025654689003298494j) . Residual of determinant:  2.4108109089523407e-12
#
#
#      --------------------  175/201: wavelength: 1.57395e-06  --------------------
#
# Scaled beta:  (59.889621490397744-0.00032521083552179816j) . Residual of determinant:  7.027983596178253e-14
#
#
#      --------------------  176/201: wavelength: 1.574375e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.87348869268694-0.00040350898868411354j) . Residual of determinant:  9.211267373380513e-12
#
#
#      --------------------  177/201: wavelength: 1.5748000000000002e-06  --------------------
#
# Scaled beta:  (59.857406632897636-0.00047201353235494785j) . Residual of determinant:  7.907658678454027e-12
#
#
#      --------------------  178/201: wavelength: 1.575225e-06  --------------------
#
# Scaled beta:  (59.84136779465838-0.0004986370023754791j) . Residual of determinant:  9.732742252668919e-12
#
#
#      --------------------  179/201: wavelength: 1.5756500000000001e-06  --------------------
#
# Scaled beta:  (59.82533562204258-0.0004664836740549399j) . Residual of determinant:  2.881793473420408e-12
#
#
#      --------------------  180/201: wavelength: 1.576075e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# scaling guess: 4
# Scaled beta:  (59.80927534413296-0.0003953644199321235j) . Residual of determinant:  2.4036103976016786e-12
#
#
#      --------------------  181/201: wavelength: 1.5765e-06  --------------------
#
# Scaled beta:  (59.79318220072463-0.00031726360267687697j) . Residual of determinant:  2.808258454909148e-11
#
#
#      --------------------  182/201: wavelength: 1.5769250000000002e-06  --------------------
#
# Scaled beta:  (59.77706950693653-0.00025005405452366964j) . Residual of determinant:  4.4456688105083095e-11
#
#
#      --------------------  183/201: wavelength: 1.57735e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# Scaled beta:  (59.76095073854989-0.00019773824715446127j) . Residual of determinant:  1.371846465461824e-10
#
#
#      --------------------  184/201: wavelength: 1.5777750000000001e-06  --------------------
#
# scaling guess: 1
# scaling guess: 2
# scaling guess: 3
# scaling guess: 4
# scaling guess: 5
# Scaled beta:  (59.74483431023504-0.00015846464706554782j) . Residual of determinant:  6.77087772126263e-11
#
#
#      --------------------  185/201: wavelength: 1.5782e-06  --------------------
#
# Scaled beta:  (59.72872457614389-0.00012917782828262824j) . Residual of determinant:  1.7892221643832076e-11
#
#
#      --------------------  186/201: wavelength: 1.578625e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.71262356345005-0.00010719374710273031j) . Residual of determinant:  6.318978140024795e-11
#
#
#      --------------------  187/201: wavelength: 1.5790500000000002e-06  --------------------
#
# Scaled beta:  (59.69653211874188-9.04912582782392e-05j) . Residual of determinant:  7.280395146356476e-11
#
#
#      --------------------  188/201: wavelength: 1.579475e-06  --------------------
#
# Scaled beta:  (59.680450523535846-7.762571121775368e-05j) . Residual of determinant:  1.3382915516386737e-12
#
#
#      --------------------  189/201: wavelength: 1.5799000000000001e-06  --------------------
#
# Scaled beta:  (59.6643788009674-6.757964819421572e-05j) . Residual of determinant:  1.4301704427744624e-10
#
#
#      --------------------  190/201: wavelength: 1.580325e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.6483168638597-5.9635491520223015e-05j) . Residual of determinant:  7.090311104375677e-11
#
#
#      --------------------  191/201: wavelength: 1.58075e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.63226458476745-5.328275760756503e-05j) . Residual of determinant:  1.926250359018521e-10
#
#
#      --------------------  192/201: wavelength: 1.5811750000000002e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.61622182820006-4.8153996425328056e-05j) . Residual of determinant:  2.100412721331532e-10
#
#
#      --------------------  193/201: wavelength: 1.5816e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.60018846462524-4.398133333368896e-05j) . Residual of determinant:  2.3325996108166175e-10
#
#
#      --------------------  194/201: wavelength: 1.5820250000000001e-06  --------------------
#
# Scaled beta:  (59.584164375771174-4.056703412623602e-05j) . Residual of determinant:  3.98987754042573e-10
#
#
#      --------------------  195/201: wavelength: 1.58245e-06  --------------------
#
# scaling guess: 1
# Scaled beta:  (59.56814945585757-3.776344911886866e-05j) . Residual of determinant:  2.6657112812842333e-10
#
#
#      --------------------  196/201: wavelength: 1.582875e-06  --------------------
#
# Scaled beta:  (59.55214361100919-3.5459218044550033e-05j) . Residual of determinant:  1.8861062158313428e-10
#
#
#      --------------------  197/201: wavelength: 1.5833000000000002e-06  --------------------
#
# Scaled beta:  (59.53614675794244-3.3569678887118285e-05j) . Residual of determinant:  1.3899743349110179e-11
#
#
#      --------------------  198/201: wavelength: 1.583725e-06  --------------------
#
# Scaled beta:  (59.52015882244111-3.203012824138509e-05j) . Residual of determinant:  7.956430645142101e-11
#
#
#      --------------------  199/201: wavelength: 1.5841500000000001e-06  --------------------
#
# Scaled beta:  (59.50417973785471-3.079104059966645e-05j) . Residual of determinant:  4.6095826787306716e-11
#
#
#      --------------------  200/201: wavelength: 1.584575e-06  --------------------
#
# Scaled beta:  (59.48820944371284-2.9814653387443488e-05j) . Residual of determinant:  9.98323416757622e-12
#
#
#      --------------------  201/201: wavelength: 1.585e-06  --------------------
#
# Scaled beta:  (59.47224788448137-2.907252059580759e-05j) . Residual of determinant:  1.524580691503902e-10

# %%
# %matplotlib notebook
plt.figure(figsize=(8,5))
plt.plot(wls, -betas2.imag, color='green', linewidth=.9, marker='o', 
        markersize=3, markerfacecolor='white')
plt.plot(wls, -betas1.imag, color='blue', linewidth=.9, marker='o', 
        markersize=3, markerfacecolor='white')

plt.yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
ls
# Out:
# driver.py  k_001_scaled_betas.npy  Mesh_Check.ipynb  outputs/
# graph.py   medium.sh*              modes/            Wavelength_Study.ipynb

# %%
np.save('k_001_subint_150_1585_201_scaled_betas', betas2)

# %%
ls
# Out:
# driver.py                                   Mesh_Check.ipynb
# graph.py                                    modes/
# k_001_scaled_betas.npy                      outputs/
# k_001_subint_150_1585_201_scaled_betas.npy  Wavelength_Study.ipynb
# medium.sh*

# %% [markdown]
# # Medium Loss polymer

# %%
n = 300
wls = np.linspace(1.4e-6, 2e-6, n+1)
betas3 = np.zeros_like(wls, dtype=complex)
outer = 'h2'
nu = 1

n_air = 1.00027717
n_glass = 1.4388164768221814
n_poly = 1.5 - .005j

# %%
for i, wl in enumerate(wls):
    print(5 * ' ' +  + 20 * '-' + '  ' + str(i+1) + '/' + str(n+1) + ': ' +
          'wavelength: ' +  str(wls[i]) + '  ' +  20 * '-' +5 * ' '+'\n')
    
    A = BraggExact(ts=ts, ns=ns , mats=mats,maxhs=maxhs, wl=wl)
    k_low = A.ks[0] * A.scale
    guess = np.array(.9999 * k_low)
    imag = 0
    flag = True
    reduce = 0

    while flag:
        try:
            x0 = np.array(guess + imag*1j)
            beta = newton(A.determinant, x0, args=(nu, outer), tol = 1e-17)
            if beta.real > k_low:
                print("Captured wrong mode, retrying.")
                raise RuntimeError
            elif beta.imag > 0:
                print("Positive imaginary part, retrying.")
                imag = -beta.imag
                guess *= 1/.999995
                raise RuntimeError
            else:
                print("Scaled beta: ", beta, ". Residual of determinant: ", 
                      abs(A.determinant(beta, nu, outer)), '\n\n' )
                imag = beta.imag
                flag=False
        except RuntimeError:
            guess *= .999995
            reduce += 1
            print("scaling guess: " + str(reduce), flush=True)
    betas3[i] = beta

# %%
# %matplotlib notebook
plt.figure(figsize=(8,5))
plt.plot(wls, -betas2.imag, color='green', linewidth=.9)
plt.plot(wls, -betas1.imag, color='blue', linewidth=.9)
plt.plot(wls, -betas3.imag, color='red', linewidth=.9)

plt.yscale('log')

# %% [markdown]
# # High Loss Polymer

# %%
n = 300
wls = np.linspace(1.4e-6, 2e-6, n+1)
betas4 = np.zeros_like(wls, dtype=complex)
outer = 'h2'
nu = 1

n_air = 1.00027717
n_glass = 1.4388164768221814
n_poly = 1.5 - .01j

# %%
for i, wl in enumerate(wls):
    print(5 * ' ' +  + 20 * '-' + '  ' + str(i+1) + '/' + str(n+1) + ': ' +
          'wavelength: ' +  str(wls[i]) + '  ' +  20 * '-' +5 * ' '+'\n')
    
    A = BraggExact(ts=ts, ns=ns , mats=mats,maxhs=maxhs, wl=wl)
    k_low = A.ks[0] * A.scale
    guess = np.array(.9999 * k_low)
    imag = 0
    flag = True
    reduce = 0

    while flag:
        try:
            x0 = np.array(guess + imag*1j)
            beta = newton(A.determinant, x0, args=(nu, outer), tol = 1e-17)
            if beta.real > k_low:
                print("Captured wrong mode, retrying.")
                raise RuntimeError
            elif beta.imag > 0:
                print("Positive imaginary part, retrying.")
                imag = -beta.imag
                guess *= 1/.999995
                raise RuntimeError
            else:
                print("Scaled beta: ", beta, ". Residual of determinant: ", 
                      abs(A.determinant(beta, nu, outer)), '\n\n' )
                imag = beta.imag
                flag=False
        except RuntimeError:
            guess *= .999995
            reduce += 1
            print("scaling guess: " + str(reduce), flush=True)
    betas4[i] = beta

# %%
# %matplotlib notebook
plt.figure(figsize=(8,5))
plt.plot(wls, -betas2.imag, color='green', linewidth=.9)
plt.plot(wls, -betas1.imag, color='blue', linewidth=.9)
plt.plot(wls, -betas3.imag, color='red', linewidth=.9)
plt.plot(wls, -betas4.imag, color='orange', linewidth=.9)

plt.yscale('log')

# %%
np.save('no_loss_betas', -betas1.imag)
np.save('low_loss_betas', -betas2.imag)
np.save('med_loss_betas', -betas3.imag)
np.save('high_loss_betas', -betas4.imag)

# %% [markdown]
# # Comparison Graph

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 300
wls = np.linspace(1.4e-6, 2e-6, n+1)

B1 = np.load('data/no_loss_betas.npy')
B2 = np.load('data/low_loss_betas.npy')
B3 = np.load('data/med_loss_betas.npy')
B4 = np.load('data/high_loss_betas.npy')

# %%
plt.figure(figsize=(10,7))
plt.plot(wls, B1, label='$k = 0.000$', linewidth=.9)
plt.plot(wls, B2, label='$k=0.001$', linewidth=.9)
plt.plot(wls, B3, label='$k=0.005$', linewidth=.9)
plt.plot(wls, B4, label='$k=0.010$', linewidth=.9)
plt.legend()
plt.title("Spectral Loss Comparison for Lossy Polymer\n")
plt.yscale('log')

# %%
b1 = 20 / np.log(10) * np.load('data/no_loss_betas.npy')/A.scale
b2 = 20 / np.log(10) * np.load('data/low_loss_betas.npy')/A.scale
b3 = 20 / np.log(10) * np.load('data/med_loss_betas.npy')/A.scale
b4 = 20 / np.log(10) * np.load('data/high_loss_betas.npy')/A.scale

# %%
n0 = np.load('data/N0_betas.npy')

N0 = 20/np.log(10)*n0/A.scale

# %%
plt.figure(figsize=(10,7))
plt.plot(wls, N0, label='N0', linewidth=1)
plt.plot(wls, b1, label='no loss', linewidth=.9)
plt.plot(wls, b2, label='low loss', linewidth=.9)
plt.plot(wls, b3, label='medium loss', linewidth=.9)
plt.plot(wls, b4, label='high loss', linewidth=.9)
plt.legend()
plt.title("Spectral Loss Comparison for Lossy Polymer\n")
plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_40037/1471926927.py in <cell line: 2>()
#       1 plt.figure(figsize=(10,7))
# ----> 2 plt.plot(wls, N0, label='N0', linewidth=1)
#       3 plt.plot(wls, b1, label='k = 0', linewidth=.9)
#       4 plt.plot(wls, b2, label='low loss', linewidth=.9)
#       5 plt.plot(wls, b3, label='medium loss', linewidth=.9)
#
# NameError: name 'N0' is not defined

# %%
np.save('data/no_loss_CL', b1)
np.save('data/low_loss_CL', b2)
np.save('data/med_loss_CL', b3)
np.save('data/high_loss_CL', b4)
np.save('data/N0_CL', N0)
