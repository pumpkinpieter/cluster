# %% [markdown]
# # Embedding of ARF microtubes
#
# This is an exploratory notebook for examining the embedding parameter of arf microtubes and the sensitivity of loss to that factor.

# %%
import ngsolve as ng
import numpy as np
import matplotlib.pyplot as plt
from ngsolve.webgui import Draw

from fiberamp.fiber.microstruct.arf import ARF
# Out:
# importing NGSolve-6.2.2202-18-gcd039cbb4

# %%
# Added embedding factor e to init parameters
a = ARF(name='poletti', outermaterials='air', freecapil=False, e=.25)
# Out:
#   Generating new mesh.
#   Refining ARF mesh uniformly 0 times: each element split into four
#   Elements/wavelength revised:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength revised: 0.363636 (glass), 0.06 (outer)
# ModeSolver: Checking if mesh has required regions
# Mesh has  10088  elements,  5057  points,  and  15144  edges.

# %%
Draw(a.mesh)
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2202-18-gcd039cbb4', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, 'd…
# BaseWebGuiScene

# %%
l =  a.n_air * a.k
z_guess = a.sqrZfrom(.999*l)**.5
z_guess
# Out:
# 2.341668296282869

# %%
zs, y, _, beta, _, _ = a.leakymode(p=2, ctr=2.24, rad=.1, niterations=12, npts=2, nrestarts=0, nspan=2,
                                    rhoinv=.9, quadrule='ellipse_trapez_shift')
# Out:
# ModeSolver.leakymode called on object with these settings:
#  ARF Physical Parameters:
#   Rc = 1 x 15 x 1e-6 meters
#   tclad = 0.666667 x 15 x 1e-6 meters
#   touter = 3.33333 x 15 x 1e-6 meters
#   t = 0.028 x 15 x 1e-6 meters
#   d = 0.14 x 15 x 1e-6 meters
#   Rti = 12.48 x 15 x 1e-6 meters
#   Rto = 12.9 x 15 x 1e-6 meters
#   Wavelength = 1.8e-06 meters
#   Refractive indices: 1.00028 (air), 1.43882 (Si)
# Nondimensional Computational Parameters:
#   Divide all lengths above by 15 x 1e-6
#   to get the actual computational lengths used.
#   Cladding starts at Rcladi = 2.713
#   PML starts at R = 4.04633 and ends at Rout = 7.37967
#   Mesh sizes: 0.04 (capillary), 0.25 (air), 0.1 (inner core)
#   Mesh sizes: 0.33 (glass), 2 (outer)
#   Elements/wavelength:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength: 0.363636 (glass), 0.06 (outer)
#   With embedded capillaries, e/t = 0.25.
# Set freq-dependent PML with p= 2  alpha= 1 and thickness=3.333
#
# SpectralProj: Setting shifted trapezoidal rule on elliptical contour
# SpectralProjNGPoly: Checking if A[d] is nonzero & Hermitian.
# SpectralProjNG: Checking if inverse.H works for umfpack
# SpectralProjNGPoly: Computing resolvents along the contour using
#                     inverse type umfpack (installed default umfpack)
# SpectralProjNGPoly: Factorizing 20201x20201 system at z =  +2.240 +0.010j
# SpectralProjNGPoly: Factorizing 20201x20201 system at z =  +2.240 -0.010j
#
# =========== Starting FEAST iterations ===========
# Trying with 2 vectors:
#
#  ITERATION 1 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [6.9e-04 7.9e+03]
#    Real part of computed eigenvalues:
#    [2.24792577 2.30221799]
#    Imag part of computed eigenvalues:
#    [2.61528824e-07 4.73402029e-01]
#    Relative Hausdorff distance from prior iterate: 4.464e+99
#
#  ITERATION 2 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [0.6 0. ]
#    Real part of computed eigenvalues:
#    [2.24792455 2.36094931]
#    Imag part of computed eigenvalues:
#    [-1.43234480e-08 -2.20202932e-04]
#    Relative Hausdorff distance from prior iterate: 2.127e-01
#
#  ITERATION 3 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [9.4e-03 7.8e+02]
#    Real part of computed eigenvalues:
#    [2.24792455 2.36097528]
#    Imag part of computed eigenvalues:
#    [-1.4323269e-08 -1.9325735e-04]
#    Relative Hausdorff distance from prior iterate: 1.671e-05
#
#    Removing ew#[0] not enclosed by contour
#  ITERATION 4 with 1 vectors and 1 left vectors
#    During kernel cleaning abs(g):
#    [0.]
#    Real part of computed eigenvalues:
#    [2.24792455]
#    Imag part of computed eigenvalues:
#    [-1.43232694e-08]
#    Relative Hausdorff distance from prior iterate: 6.214e-16
#
#
# ***FEAST converged with:
# 	Relative Hausdorff distance = 6.214e-16
#
# ============= FEAST iterations done =============
#    Normalizing by M-norms: max=1.0e+00, min=1.0e+00
#    Normalizing by M-norms: max=2.2e+02, min=2.2e+02
# Results:
#  Z: [2.24792455-1.43232694e-08j]
#  beta: [3488408.47410003+4.10217364e-05j]
#  CL dB/m: [0.00035631]
# Mode boundary L² norm = 2.1e-06
# *** Mode boundary L2 norm > 1e-6!
# PML decay estimates boundary norm ~ 8.8e-01

# %%
for f in y:
    Draw(f, a.mesh)
# Out:
# WebGuiWidget(value={'ngsolve_version': '6.2.2202-18-gcd039cbb4', 'mesh_dim': 2, 'order2d': 2, 'order3d': 2, 'd…

# %%
CL = 20 * beta.imag / np.log(10)
zs.real, CL
# Out:
# (array([2.24792455]), array([0.00035631]))

# %% [markdown]
# # Let's set up a parameter study here with low p values, just to debug the process
#
# We can also just see what the graph looks like for low p.

# %%
es = np.linspace(.01, 1, 6)
Zs = np.zeros_like(es, dtype=complex)
betas = np.zeros_like(es, dtype=complex)

# %%
for i,e in enumerate(es):
    
    a = ARF(name='poletti', outermaterials='air', freecapil=False, e=e)
    
    zs, y, _, beta, _, _ = a.leakymode(p=4, ctr=2.247, rad=.01, niterations=12, npts=2, nrestarts=0, nspan=2,
                                        rhoinv=.9, quadrule='ellipse_trapez_shift')
    betas[i] = beta[0]
    Zs[i] = zs[0]
# Out:
#   Generating new mesh.
#   Refining ARF mesh uniformly 0 times: each element split into four
#   Elements/wavelength revised:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength revised: 0.363636 (glass), 0.06 (outer)
# ModeSolver: Checking if mesh has required regions
# Mesh has  10084  elements,  5055  points,  and  15138  edges.
# ModeSolver.leakymode called on object with these settings:
#  ARF Physical Parameters:
#   Rc = 1 x 15 x 1e-6 meters
#   tclad = 0.666667 x 15 x 1e-6 meters
#   touter = 3.33333 x 15 x 1e-6 meters
#   t = 0.028 x 15 x 1e-6 meters
#   d = 0.14 x 15 x 1e-6 meters
#   Rti = 12.48 x 15 x 1e-6 meters
#   Rto = 12.9 x 15 x 1e-6 meters
#   Wavelength = 1.8e-06 meters
#   Refractive indices: 1.00028 (air), 1.43882 (Si)
# Nondimensional Computational Parameters:
#   Divide all lengths above by 15 x 1e-6
#   to get the actual computational lengths used.
#   Cladding starts at Rcladi = 2.71972
#   PML starts at R = 4.05305 and ends at Rout = 7.38639
#   Mesh sizes: 0.04 (capillary), 0.25 (air), 0.1 (inner core)
#   Mesh sizes: 0.33 (glass), 2 (outer)
#   Elements/wavelength:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength: 0.363636 (glass), 0.06 (outer)
#   With embedded capillaries, e/t = 0.01.
# Set freq-dependent PML with p= 4  alpha= 1 and thickness=3.333
#
# SpectralProj: Setting shifted trapezoidal rule on elliptical contour
# SpectralProjNGPoly: Checking if A[d] is nonzero & Hermitian.
# SpectralProjNG: Checking if inverse.H works for umfpack
# SpectralProjNGPoly: Computing resolvents along the contour using
#                     inverse type umfpack (installed default umfpack)
# SpectralProjNGPoly: Factorizing 80721x80721 system at z =  +2.247 +0.001j
# SpectralProjNGPoly: Factorizing 80721x80721 system at z =  +2.247 -0.001j
#
# =========== Starting FEAST iterations ===========
# Trying with 2 vectors:
#
#  ITERATION 1 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [1.0e-06 8.6e+03]
#    Real part of computed eigenvalues:
#    [2.17164083 2.24774762]
#    Imag part of computed eigenvalues:
#    [ 1.81878958e-02 -5.65190313e-06]
#    Relative Hausdorff distance from prior iterate: 4.450e+99
#
#  ITERATION 2 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [0. 0.]
#    Real part of computed eigenvalues:
#    [2.13520742 2.24774763]
#    Imag part of computed eigenvalues:
#    [-1.29602937e-01 -5.65032246e-06]
#    Relative Hausdorff distance from prior iterate: 6.774e-02
#
#  ITERATION 3 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [2.0e-04 4.9e+03]
#    Real part of computed eigenvalues:
#    [2.12607145 2.24774763]
#    Imag part of computed eigenvalues:
#    [-1.11791719e-01 -5.65032246e-06]
#    Relative Hausdorff distance from prior iterate: 8.909e-03
#
#    Removing ew#[0] not enclosed by contour
#  ITERATION 4 with 1 vectors and 1 left vectors
#    During kernel cleaning abs(g):
#    [0.]
#    Real part of computed eigenvalues:
#    [2.24774763]
#    Imag part of computed eigenvalues:
#    [-5.65032246e-06]
#    Relative Hausdorff distance from prior iterate: 8.079e-16
#
#
# ***FEAST converged with:
# 	Relative Hausdorff distance = 8.079e-16
#
# ============= FEAST iterations done =============
#    Normalizing by M-norms: max=3.3e+00, min=3.3e+00
#    Normalizing by M-norms: max=4.1e+02, min=4.1e+02
# Results:
#  Z: [2.24774763-5.65032246e-06j]
#  beta: [3488408.98079622+0.01618121j]
#  CL dB/m: [0.14054816]
# Mode boundary L² norm = 3.8e-05
# *** Mode boundary L2 norm > 1e-6!
# PML decay estimates boundary norm ~ 8.8e-01
#   Generating new mesh.
#   Refining ARF mesh uniformly 0 times: each element split into four
#   Elements/wavelength revised:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength revised: 0.363636 (glass), 0.06 (outer)
# ModeSolver: Checking if mesh has required regions
# Mesh has  10068  elements,  5047  points,  and  15114  edges.
# ModeSolver.leakymode called on object with these settings:
#  ARF Physical Parameters:
#   Rc = 1 x 15 x 1e-6 meters
#   tclad = 0.666667 x 15 x 1e-6 meters
#   touter = 3.33333 x 15 x 1e-6 meters
#   t = 0.028 x 15 x 1e-6 meters
#   d = 0.14 x 15 x 1e-6 meters
#   Rti = 12.48 x 15 x 1e-6 meters
#   Rto = 12.9 x 15 x 1e-6 meters
#   Wavelength = 1.8e-06 meters
#   Refractive indices: 1.00028 (air), 1.43882 (Si)
# Nondimensional Computational Parameters:
#   Divide all lengths above by 15 x 1e-6
#   to get the actual computational lengths used.
#   Cladding starts at Rcladi = 2.71418
#   PML starts at R = 4.04751 and ends at Rout = 7.38084
#   Mesh sizes: 0.04 (capillary), 0.25 (air), 0.1 (inner core)
#   Mesh sizes: 0.33 (glass), 2 (outer)
#   Elements/wavelength:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength: 0.363636 (glass), 0.06 (outer)
#   With embedded capillaries, e/t = 0.208.
# Set freq-dependent PML with p= 4  alpha= 1 and thickness=3.333
#
# SpectralProj: Setting shifted trapezoidal rule on elliptical contour
# SpectralProjNGPoly: Checking if A[d] is nonzero & Hermitian.
# SpectralProjNG: Checking if inverse.H works for umfpack
# SpectralProjNGPoly: Computing resolvents along the contour using
#                     inverse type umfpack (installed default umfpack)
# SpectralProjNGPoly: Factorizing 80593x80593 system at z =  +2.247 +0.001j
# SpectralProjNGPoly: Factorizing 80593x80593 system at z =  +2.247 -0.001j
#
# =========== Starting FEAST iterations ===========
# Trying with 2 vectors:
#
#  ITERATION 1 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [2.6e-06 8.6e+03]
#    Real part of computed eigenvalues:
#    [2.13951762 2.24774664]
#    Imag part of computed eigenvalues:
#    [-6.44640584e-02 -1.03196230e-06]
#    Relative Hausdorff distance from prior iterate: 4.450e+99
#
#  ITERATION 2 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [0. 0.]
#    Real part of computed eigenvalues:
#    [2.08239096 2.24774664]
#    Imag part of computed eigenvalues:
#    [-8.89999102e-02 -1.03190389e-06]
#    Relative Hausdorff distance from prior iterate: 2.767e-02
#
#  ITERATION 3 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [2.1e-05 8.5e+03]
#    Real part of computed eigenvalues:
#    [2.08312644 2.24774664]
#    Imag part of computed eigenvalues:
#    [-8.88226906e-02 -1.03190389e-06]
#    Relative Hausdorff distance from prior iterate: 3.367e-04
#
#    Removing ew#[0] not enclosed by contour
#  ITERATION 4 with 1 vectors and 1 left vectors
#    During kernel cleaning abs(g):
#    [0.]
#    Real part of computed eigenvalues:
#    [2.24774664]
#    Imag part of computed eigenvalues:
#    [-1.03190389e-06]
#    Relative Hausdorff distance from prior iterate: 2.767e-15
#
#
# ***FEAST converged with:
# 	Relative Hausdorff distance = 2.767e-15
#
# ============= FEAST iterations done =============
#    Normalizing by M-norms: max=4.5e+00, min=4.5e+00
#    Normalizing by M-norms: max=5.0e+02, min=5.0e+02
# Results:
#  Z: [2.24774664-1.03190389e-06j]
#  beta: [3488408.98361508+0.00295513j]
#  CL dB/m: [0.02566794]
# Mode boundary L² norm = 1.9e-05
# *** Mode boundary L2 norm > 1e-6!
# PML decay estimates boundary norm ~ 8.8e-01
#   Generating new mesh.
#   Refining ARF mesh uniformly 0 times: each element split into four
#   Elements/wavelength revised:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength revised: 0.363636 (glass), 0.06 (outer)
# ModeSolver: Checking if mesh has required regions
# Mesh has  10088  elements,  5057  points,  and  15144  edges.
# ModeSolver.leakymode called on object with these settings:
#  ARF Physical Parameters:
#   Rc = 1 x 15 x 1e-6 meters
#   tclad = 0.666667 x 15 x 1e-6 meters
#   touter = 3.33333 x 15 x 1e-6 meters
#   t = 0.028 x 15 x 1e-6 meters
#   d = 0.14 x 15 x 1e-6 meters
#   Rti = 12.48 x 15 x 1e-6 meters
#   Rto = 12.9 x 15 x 1e-6 meters
#   Wavelength = 1.8e-06 meters
#   Refractive indices: 1.00028 (air), 1.43882 (Si)
# Nondimensional Computational Parameters:
#   Divide all lengths above by 15 x 1e-6
#   to get the actual computational lengths used.
#   Cladding starts at Rcladi = 2.70863
#   PML starts at R = 4.04197 and ends at Rout = 7.3753
#   Mesh sizes: 0.04 (capillary), 0.25 (air), 0.1 (inner core)
#   Mesh sizes: 0.33 (glass), 2 (outer)
#   Elements/wavelength:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength: 0.363636 (glass), 0.06 (outer)
#   With embedded capillaries, e/t = 0.406.
# Set freq-dependent PML with p= 4  alpha= 1 and thickness=3.333
# SpectralProj: Setting shifted trapezoidal rule on elliptical contour
# SpectralProjNGPoly: Checking if A[d] is nonzero & Hermitian.
# SpectralProjNG: Checking if inverse.H works for umfpack
# SpectralProjNGPoly: Computing resolvents along the contour using
#                     inverse type umfpack (installed default umfpack)
# SpectralProjNGPoly: Factorizing 80753x80753 system at z =  +2.247 +0.001j
# SpectralProjNGPoly: Factorizing 80753x80753 system at z =  +2.247 -0.001j
#
# =========== Starting FEAST iterations ===========
# Trying with 2 vectors:
#
#  ITERATION 1 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [1.9e-05 7.9e+03]
#    Real part of computed eigenvalues:
#    [2.19389258 2.24774486]
#    Imag part of computed eigenvalues:
#    [-2.56354655e-02 -2.29318570e-06]
#    Relative Hausdorff distance from prior iterate: 4.450e+99
#
#  ITERATION 2 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [0. 0.]
#    Real part of computed eigenvalues:
#    [2.18973171 2.24774486]
#    Imag part of computed eigenvalues:
#    [-6.62496490e-02 -2.29240378e-06]
#    Relative Hausdorff distance from prior iterate: 1.817e-02
#
#  ITERATION 3 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [1.3e-04 5.0e+03]
#    Real part of computed eigenvalues:
#    [2.17472758 2.24774486]
#    Imag part of computed eigenvalues:
#    [-7.53358058e-02 -2.29240378e-06]
#    Relative Hausdorff distance from prior iterate: 7.806e-03
#
#    Removing ew#[0] not enclosed by contour
#  ITERATION 4 with 1 vectors and 1 left vectors
#    During kernel cleaning abs(g):
#    [0.]
#    Real part of computed eigenvalues:
#    [2.24774486]
#    Imag part of computed eigenvalues:
#    [-2.29240378e-06]
#    Relative Hausdorff distance from prior iterate: 2.769e-15
#
#
# ***FEAST converged with:
# 	Relative Hausdorff distance = 2.769e-15
#
# ============= FEAST iterations done =============
#    Normalizing by M-norms: max=3.1e+00, min=3.1e+00
#    Normalizing by M-norms: max=4.1e+02, min=4.1e+02
# Results:
#  Z: [2.24774486-2.29240378e-06j]
#  beta: [3488408.98870694+0.0065649j]
#  CL dB/m: [0.05702201]
# Mode boundary L² norm = 2.9e-05
# *** Mode boundary L2 norm > 1e-6!
# PML decay estimates boundary norm ~ 8.8e-01
#   Generating new mesh.
#   Refining ARF mesh uniformly 0 times: each element split into four
#   Elements/wavelength revised:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength revised: 0.363636 (glass), 0.06 (outer)
# ModeSolver: Checking if mesh has required regions
# Mesh has  10034  elements,  5030  points,  and  15063  edges.
# ModeSolver.leakymode called on object with these settings:
#  ARF Physical Parameters:
#   Rc = 1 x 15 x 1e-6 meters
#   tclad = 0.666667 x 15 x 1e-6 meters
#   touter = 3.33333 x 15 x 1e-6 meters
#   t = 0.028 x 15 x 1e-6 meters
#   d = 0.14 x 15 x 1e-6 meters
#   Rti = 12.48 x 15 x 1e-6 meters
#   Rto = 12.9 x 15 x 1e-6 meters
#   Wavelength = 1.8e-06 meters
#   Refractive indices: 1.00028 (air), 1.43882 (Si)
# Nondimensional Computational Parameters:
#   Divide all lengths above by 15 x 1e-6
#   to get the actual computational lengths used.
#   Cladding starts at Rcladi = 2.70309
#   PML starts at R = 4.03642 and ends at Rout = 7.36975
#   Mesh sizes: 0.04 (capillary), 0.25 (air), 0.1 (inner core)
#   Mesh sizes: 0.33 (glass), 2 (outer)
#   Elements/wavelength:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength: 0.363636 (glass), 0.06 (outer)
#   With embedded capillaries, e/t = 0.604.
# Set freq-dependent PML with p= 4  alpha= 1 and thickness=3.333
#
# SpectralProj: Setting shifted trapezoidal rule on elliptical contour
# SpectralProjNGPoly: Checking if A[d] is nonzero & Hermitian.
# SpectralProjNG: Checking if inverse.H works for umfpack
# SpectralProjNGPoly: Computing resolvents along the contour using
#                     inverse type umfpack (installed default umfpack)
# SpectralProjNGPoly: Factorizing 80321x80321 system at z =  +2.247 +0.001j
# SpectralProjNGPoly: Factorizing 80321x80321 system at z =  +2.247 -0.001j
#
# =========== Starting FEAST iterations ===========
# Trying with 2 vectors:
#
#  ITERATION 1 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [9.9e-07 8.6e+03]
#    Real part of computed eigenvalues:
#    [1.91248765 2.24774696]
#    Imag part of computed eigenvalues:
#    [-8.09942200e-02 -1.05293087e-06]
#    Relative Hausdorff distance from prior iterate: 4.450e+99
#
#  ITERATION 2 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [0. 0.]
#    Real part of computed eigenvalues:
#    [2.06896156 2.24774696]
#    Imag part of computed eigenvalues:
#    [-4.58721275e-02 -1.05277815e-06]
#    Relative Hausdorff distance from prior iterate: 7.137e-02
#
#  ITERATION 3 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [3.8e-06 2.4e+03]
#    Real part of computed eigenvalues:
#    [2.06838331 2.24774696]
#    Imag part of computed eigenvalues:
#    [-4.59274196e-02 -1.05277814e-06]
#    Relative Hausdorff distance from prior iterate: 2.585e-04
#
#    Removing ew#[0] not enclosed by contour
#  ITERATION 4 with 1 vectors and 1 left vectors
#    During kernel cleaning abs(g):
#    [0.]
#    Real part of computed eigenvalues:
#    [2.24774696]
#    Imag part of computed eigenvalues:
#    [-1.05277814e-06]
#    Relative Hausdorff distance from prior iterate: 9.917e-16
#
#
# ***FEAST converged with:
# 	Relative Hausdorff distance = 9.917e-16
#
# ============= FEAST iterations done =============
#    Normalizing by M-norms: max=2.5e+00, min=2.5e+00
#    Normalizing by M-norms: max=2.4e+02, min=2.4e+02
# Results:
#  Z: [2.24774696-1.05277814e-06j]
#  beta: [3488408.98269101+0.00301491j]
#  CL dB/m: [0.02618718]
# Mode boundary L² norm = 1.8e-05
# *** Mode boundary L2 norm > 1e-6!
# PML decay estimates boundary norm ~ 8.8e-01
#   Generating new mesh.
#   Refining ARF mesh uniformly 0 times: each element split into four
#   Elements/wavelength revised:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength revised: 0.363636 (glass), 0.06 (outer)
# ModeSolver: Checking if mesh has required regions
# Mesh has  10110  elements,  5068  points,  and  15177  edges.
# ModeSolver.leakymode called on object with these settings:
#  ARF Physical Parameters:
#   Rc = 1 x 15 x 1e-6 meters
#   tclad = 0.666667 x 15 x 1e-6 meters
#   touter = 3.33333 x 15 x 1e-6 meters
#   t = 0.028 x 15 x 1e-6 meters
#   d = 0.14 x 15 x 1e-6 meters
#   Rti = 12.48 x 15 x 1e-6 meters
#   Rto = 12.9 x 15 x 1e-6 meters
#   Wavelength = 1.8e-06 meters
#   Refractive indices: 1.00028 (air), 1.43882 (Si)
# Nondimensional Computational Parameters:
#   Divide all lengths above by 15 x 1e-6
#   to get the actual computational lengths used.
#   Cladding starts at Rcladi = 2.69754
#   PML starts at R = 4.03088 and ends at Rout = 7.36421
#   Mesh sizes: 0.04 (capillary), 0.25 (air), 0.1 (inner core)
#   Mesh sizes: 0.33 (glass), 2 (outer)
#   Elements/wavelength:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength: 0.363636 (glass), 0.06 (outer)
#   With embedded capillaries, e/t = 0.802.
# Set freq-dependent PML with p= 4  alpha= 1 and thickness=3.333
#
# SpectralProj: Setting shifted trapezoidal rule on elliptical contour
# SpectralProjNGPoly: Checking if A[d] is nonzero & Hermitian.
# SpectralProjNG: Checking if inverse.H works for umfpack
# SpectralProjNGPoly: Computing resolvents along the contour using
#                     inverse type umfpack (installed default umfpack)
# SpectralProjNGPoly: Factorizing 80929x80929 system at z =  +2.247 +0.001j
# SpectralProjNGPoly: Factorizing 80929x80929 system at z =  +2.247 -0.001j
#
# =========== Starting FEAST iterations ===========
# Trying with 2 vectors:
#
#  ITERATION 1 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [2.4e-07 8.0e+03]
#    Real part of computed eigenvalues:
#    [1.83353402 2.24774602]
#    Imag part of computed eigenvalues:
#    [-1.17857159e-01 -1.12419684e-06]
#    Relative Hausdorff distance from prior iterate: 4.450e+99
#
#  ITERATION 2 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [0. 0.]
#    Real part of computed eigenvalues:
#    [2.24774602 2.35673074]
#    Imag part of computed eigenvalues:
#    [-1.12338053e-06 -1.50698320e-01]
#    Relative Hausdorff distance from prior iterate: 1.917e-01
#
#  ITERATION 3 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [1.1e+03 4.4e-06]
#    Real part of computed eigenvalues:
#    [2.24774602 2.35678805]
#    Imag part of computed eigenvalues:
#    [-1.12338053e-06 -1.71132660e-01]
#    Relative Hausdorff distance from prior iterate: 9.094e-03
#
#    Removing ew#[1] not enclosed by contour
#  ITERATION 4 with 1 vectors and 1 left vectors
#    During kernel cleaning abs(g):
#    [0.]
#    Real part of computed eigenvalues:
#    [2.24774602]
#    Imag part of computed eigenvalues:
#    [-1.12338053e-06]
#    Relative Hausdorff distance from prior iterate: 8.028e-16
#
#
# ***FEAST converged with:
# 	Relative Hausdorff distance = 8.028e-16
#
# ============= FEAST iterations done =============
#    Normalizing by M-norms: max=1.7e+00, min=1.7e+00
#    Normalizing by M-norms: max=1.6e+02, min=1.6e+02
# Results:
#  Z: [2.24774602-1.12338053e-06j]
#  beta: [3488408.98539237+0.0032171j]
#  CL dB/m: [0.02794335]
# Mode boundary L² norm = 1.9e-05
# *** Mode boundary L2 norm > 1e-6!
# PML decay estimates boundary norm ~ 8.8e-01
#   Generating new mesh.
#   Refining ARF mesh uniformly 0 times: each element split into four
#   Elements/wavelength revised:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength revised: 0.363636 (glass), 0.06 (outer)
# ModeSolver: Checking if mesh has required regions
# Mesh has  9994  elements,  5010  points,  and  15003  edges.
# ModeSolver.leakymode called on object with these settings:
#  ARF Physical Parameters:
#   Rc = 1 x 15 x 1e-6 meters
#   tclad = 0.666667 x 15 x 1e-6 meters
#   touter = 3.33333 x 15 x 1e-6 meters
#   t = 0.028 x 15 x 1e-6 meters
#   d = 0.14 x 15 x 1e-6 meters
#   Rti = 12.48 x 15 x 1e-6 meters
#   Rto = 12.9 x 15 x 1e-6 meters
#   Wavelength = 1.8e-06 meters
#   Refractive indices: 1.00028 (air), 1.43882 (Si)
# Nondimensional Computational Parameters:
#   Divide all lengths above by 15 x 1e-6
#   to get the actual computational lengths used.
#   Cladding starts at Rcladi = 2.692
#   PML starts at R = 4.02533 and ends at Rout = 7.35867
#   Mesh sizes: 0.04 (capillary), 0.25 (air), 0.1 (inner core)
#   Mesh sizes: 0.33 (glass), 2 (outer)
#   Elements/wavelength:3 (capillary), 0.48 (air), 1.2 (inner core)
#   Elements/wavelength: 0.363636 (glass), 0.06 (outer)
#   With embedded capillaries, e/t = 1.
# Set freq-dependent PML with p= 4  alpha= 1 and thickness=3.333
#
# SpectralProj: Setting shifted trapezoidal rule on elliptical contour
# SpectralProjNGPoly: Checking if A[d] is nonzero & Hermitian.
# SpectralProjNG: Checking if inverse.H works for umfpack
# SpectralProjNGPoly: Computing resolvents along the contour using
#                     inverse type umfpack (installed default umfpack)
# SpectralProjNGPoly: Factorizing 80001x80001 system at z =  +2.247 +0.001j
# SpectralProjNGPoly: Factorizing 80001x80001 system at z =  +2.247 -0.001j
#
# =========== Starting FEAST iterations ===========
# Trying with 2 vectors:
#
#  ITERATION 1 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [1.6e-07 7.7e+03]
#    Real part of computed eigenvalues:
#    [2.2477471  2.33606107]
#    Imag part of computed eigenvalues:
#    [-1.56114199e-06  3.30565633e-01]
#    Relative Hausdorff distance from prior iterate: 4.450e+99
#
#  ITERATION 2 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [0. 0.]
#    Real part of computed eigenvalues:
#    [2.13194211 2.2477471 ]
#    Imag part of computed eigenvalues:
#    [ 2.12454322e-01 -1.56114378e-06]
#    Relative Hausdorff distance from prior iterate: 1.050e-01
#
#  ITERATION 3 with 2 vectors and 2 left vectors
#    During kernel cleaning abs(g):
#    [9.3e+02 9.8e-07]
#    Real part of computed eigenvalues:
#    [2.11942079 2.2477471 ]
#    Imag part of computed eigenvalues:
#    [-1.77701024e-01 -1.56114379e-06]
#    Relative Hausdorff distance from prior iterate: 1.077e-01
#
#    Removing ew#[1] not enclosed by contour
#  ITERATION 4 with 1 vectors and 1 left vectors
#    During kernel cleaning abs(g):
#    [0.]
#    Real part of computed eigenvalues:
#    [2.2477471]
#    Imag part of computed eigenvalues:
#    [-1.56114378e-06]
#    Relative Hausdorff distance from prior iterate: 2.022e-16
#
#
# ***FEAST converged with:
# 	Relative Hausdorff distance = 2.022e-16
#
# ============= FEAST iterations done =============
#    Normalizing by M-norms: max=4.6e-01, min=4.6e-01
#    Normalizing by M-norms: max=1.2e+03, min=1.2e+03
# Results:
#  Z: [2.2477471-1.56114378e-06j]
#  beta: [3488408.98229279+0.00447075j]
#  CL dB/m: [0.03883245]
# Mode boundary L² norm = 2.2e-05
# *** Mode boundary L2 norm > 1e-6!
# PML decay estimates boundary norm ~ 8.8e-01

# %%
CLs = 20 * betas.imag / np.log(10)

# %%
plt.plot(es, CLs)
# plt.yscale('log')
